# %%
import io
import os

from collections import defaultdict
import tensorflow as tf
import numpy as np
from keras import backend as K
from keras.layers import Conv2D, Input, BatchNormalization, LeakyReLU, ZeroPadding2D, UpSampling2D, MaxPool2D, Activation
from keras.layers.merge import add, concatenate
from keras.models import Model
from keras.utils import get_custom_objects
from tensorflow.python.platform import build_info as tf_build_info

print("TensorFlow version: {}".format(tf.__version__))
print("Eager execution: {}".format(tf.executing_eagerly()))
print("Keras version: {}".format(tf.keras.__version__))
print("Cuda version: {}".format(tf_build_info.cuda_version_number))
print("Cudnn version: {}".format(tf_build_info.cudnn_version_number))
print("Num Physical GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num Logical GPUs Available: ", len(tf.config.experimental.list_logical_devices('GPU')))


NETWORK_W          = 416
NETWORK_H          = 416


# ------------------------------------------------------------
# needs to be defined as activation class otherwise error
# AttributeError: 'Activation' object has no attribute '__name__'    
class Mish(Activation):
    
    def __init__(self, activation, **kwargs):
        super(Mish, self).__init__(activation, **kwargs)
        self.__name__ = 'mish'


def mysoftplus(x):

    mask_min = tf.cast((x<-20.0),tf.float32)
    ymin = mask_min*tf.math.exp(x)

    mask_max = tf.cast((x>20.0),tf.float32)
    ymax = mask_max*x
    
    mask= tf.cast((abs(x)<=20.0),tf.float32)
    y = mask*tf.math.log(tf.math.exp(x) + 1.0)
    
    return(ymin+ymax+y)    
        


def mish(x):
    return (x* tf.math.tanh(mysoftplus(x)))
    
   
    

get_custom_objects().update({'mish': Mish(mish)})

def _conv_block(inp, convs, skip=False):
    x = inp
    count = 0
    
    for conv in convs:
        if count == (len(convs) - 2) and skip:
            skip_connection = x
        count += 1
        
        if conv['stride'] > 1: x = ZeroPadding2D(((1,0),(1,0)), name='zerop_' + str(conv['layer_idx']))(x)  # peculiar padding as darknet prefer left and top
        
        x = Conv2D(conv['filter'], 
                   conv['kernel'], 
                   strides=conv['stride'], 
                   padding='valid' if conv['stride'] > 1 else 'same', # peculiar padding as darknet prefer left and top
                   name='convn_' + str(conv['layer_idx']) if conv['bnorm'] else 'conv_' + str(conv['layer_idx']),
                   use_bias=True)(x)
        
        if conv['bnorm']: x = BatchNormalization(name='BN_' + str(conv['layer_idx']))(x)    
        
        if conv['activ'] == 1: x = LeakyReLU(alpha=0.1, name='leaky_' + str(conv['layer_idx']))(x)
        if conv['activ'] == 2: x = Activation('mish', name='mish_' + str(conv['layer_idx']))(x) 
            
    return add([skip_connection, x],  name='add_' + str(conv['layer_idx']+1)) if skip else x

def make_yolov3_tiny_model():
        
    input_image = Input(shape=(NETWORK_H, NETWORK_W, 3), name='input_0')

    # Layer  0
    x = _conv_block(input_image, [{'filter': 16, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 0}])
    
    # Layer  1
    x = MaxPool2D(pool_size=(2, 2), strides=2, padding='same', name = 'max_1')(x)
    
    # Layer  2
    x = _conv_block(x, [{'filter': 32, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 2}])
  
    # Layer  3
    x = MaxPool2D(pool_size=(2, 2), strides=2, padding='same', name = 'max_3')(x)
    
    # Layer  4
    x = _conv_block(x, [{'filter': 64, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 4}])   

    # Layer  5
    x = MaxPool2D(pool_size=(2, 2), strides=2, padding='same', name = 'max_5')(x)
    
    # Layer  6
    x = _conv_block(x, [{'filter': 128, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 6}])   
    
    # Layer  7
    x = MaxPool2D(pool_size=(2, 2), strides=2, padding='same', name = 'max_7')(x)
    
    # Layer  8
    x = _conv_block(x, [{'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 8}])   
    layer_8 = x
    
    # Layer  9
    x = MaxPool2D(pool_size=(2, 2), strides=2, padding='same', name = 'max_9')(x)
    
    # Layer  10
    x = _conv_block(x, [{'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 10}])
    layer_10 = x
    
    # Layer  11
    x = MaxPool2D(pool_size=(2, 2), strides=1, padding='same', name = 'max_11')(x)
    
    # Layer  12
    x = _conv_block(x, [{'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 12}])

    
    ###########
    
    # Layer  13
    x = _conv_block(x, [{'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 13}]) 
    layer_13 = x
        
    # Layer  14
    x = _conv_block(x, [{'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 14}])     
    
    # Layer  15
    x = _conv_block(x, [{'filter': 255, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 0, 'layer_idx': 15}])    
    
    # Layer  16
    yolo_16 = x
    
    
    # Layer  17
    x = layer_13

    # Layer  18
    x = _conv_block(x, [{'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 18}])
   
    # Layer  19
    x = UpSampling2D(size=(2, 2), name = 'upsamp_19')(x)

    # Layer  20
    x = concatenate([layer_8, x],  name='concatenate_20')
    
    # Layer  21
    x = _conv_block(x, [{'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 21}])     
    
    # Layer  22
    x = _conv_block(x, [{'filter': 255, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 0, 'layer_idx': 22}])    
    
    # Layer  23
    yolo_23 = x   
                                      
    model = Model(input_image, [yolo_16, yolo_23], name = 'Yolo_v3_tiny')    
    return model
# Out:
# Using TensorFlow backend.
# TensorFlow version: 2.1.0
# Eager execution: True
# Keras version: 2.2.4-tf
# Cuda version: 10.1
# Cudnn version: 7
# Num Physical GPUs Available:  0
# Num Logical GPUs Available:  0

# %%
# Define the model
model = make_yolov3_tiny_model()

# %%
from keras.models import Model
import struct

class WeightReader:
    def __init__(self, weight_file):
        with open(weight_file, 'rb') as w_f:
            major,    = struct.unpack('i', w_f.read(4))
            minor,    = struct.unpack('i', w_f.read(4))
            revision, = struct.unpack('i', w_f.read(4))

            if (major*10 + minor) >= 2 and major < 1000 and minor < 1000:
                print("reading 64 bytes")
                w_f.read(8)
            else:
                print("reading 32 bytes")
                w_f.read(4)

            transpose = (major > 1000) or (minor > 1000)
            
            binary = w_f.read()

        self.offset = 0
        self.all_weights = np.frombuffer(binary, dtype='float32')
        
    def read_bytes(self, size):
        self.offset = self.offset + size
        return self.all_weights[self.offset-size:self.offset]

    def load_weights(self, model):
        count = 0
        ncount = 0
        for i in range(23):
            try:

                conv_layer = model.get_layer('convn_' + str(i))
                filter = conv_layer.kernel.shape[-1]
                nweights = np.prod(conv_layer.kernel.shape) # kernel*kernel*c*filter
                
                print("loading weights of convolution #" + str(i)+ "- nb parameters: "+str(nweights+filter))             
                
                if i  in [15, 22]:
                    print("Special processing for layer "+ str(i))
                    bias  = self.read_bytes(filter) # bias
                    weights = self.read_bytes(nweights) # weights
                
                else:                    
                    bias  = self.read_bytes(filter) # bias
                    scale = self.read_bytes(filter) # scale
                    mean  = self.read_bytes(filter) # mean
                    var   = self.read_bytes(filter) # variance
                    weights = self.read_bytes(nweights) # weights
                    
                    bias = bias - scale  * mean / (np.sqrt(var + 0.00001)) #normalize bias

                    weights = np.reshape(weights,(filter,int(nweights/filter)))  #normalize weights
                    A = scale / (np.sqrt(var + 0.00001))
                    A= np.expand_dims(A,axis=0)
                    weights = weights* A.T
                    weights = np.reshape(weights,(nweights))
                

                weights = weights.reshape(list(reversed(conv_layer.get_weights()[0].shape)))                 
                weights = weights.transpose([2,3,1,0])
                
                if len(conv_layer.get_weights()) > 1:
                    a=conv_layer.set_weights([weights, bias])
                else:    
                    a=conv_layer.set_weights([weights])
                
                count = count+1
                ncount = ncount+nweights+filter
             
            except ValueError:
                print("no convolution #" + str(i)) 
        
        print(count, "Conv normalized layers loaded ", ncount, " parameters")
    
    def reset(self):
        self.offset = 0

# %%
# Get and compute the weights
weight_reader = WeightReader('models/yolo/yolov3-tiny.weights')
weight_reader.load_weights(model)
# Out:
# reading 64 bytes
# loading weights of convolution #0- nb parameters: 448
# no convolution #1
# loading weights of convolution #2- nb parameters: 4640
# no convolution #3
# loading weights of convolution #4- nb parameters: 18496
# no convolution #5
# loading weights of convolution #6- nb parameters: 73856
# no convolution #7
# loading weights of convolution #8- nb parameters: 295168
# no convolution #9
# loading weights of convolution #10- nb parameters: 1180160
# no convolution #11
# loading weights of convolution #12- nb parameters: 4719616
# loading weights of convolution #13- nb parameters: 262400
# loading weights of convolution #14- nb parameters: 1180160
# loading weights of convolution #15- nb parameters: 130815
# Special processing for layer 15
# no convolution #16
# no convolution #17
# loading weights of convolution #18- nb parameters: 32896
# no convolution #19
# no convolution #20
# loading weights of convolution #21- nb parameters: 884992
# loading weights of convolution #22- nb parameters: 65535
# Special processing for layer 22
# 13 Conv normalized layers loaded  8849182  parameters

# %%
# save the model to file
! rm models\yolo\yolov3-tiny.h5

model.save('models/yolo/yolov3-tiny.h5')
! dir models\yolo\*.h5
# Out:
#  Le volume dans le lecteur C s'appelle Windows
#  Le num‚ro de s‚rie du volume est CCDC-AB26
#
#  R‚pertoire de C:\Users\edh\yolo4\Yolov-4\models\yolo
#
# 12/07/2020  10:16        35ÿ584ÿ360 yolov3-tiny.h5
# 11/07/2020  19:26       258ÿ879ÿ904 yolov4.h5
#                2 fichier(s)      294ÿ464ÿ264 octets
#                0 R‚p(s)  289ÿ913ÿ286ÿ656 octets libres

# %%
# Load the model
from keras.models import load_model, Model
yolo_model = load_model("models/yolo/yolov3-tiny.h5")
# Out:
# C:\Users\edh\Anaconda3\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
# Freeze the backbone

# Fine-tune from this layer onwards
fine_tune_at = "convn_13"

# Freeze all the layers before the `fine_tune_at` layer
train = False
for l in yolo_model.layers:
  if l.name == fine_tune_at:
        train = True        
  l.trainable =  train
    

# Display the trainable indicator
for l in yolo_model.layers:
    print("layer ",l.name, " trainable: ", l.trainable)
# Out:
# layer  input_0  trainable:  False
# layer  convn_0  trainable:  False
# layer  BN_0  trainable:  False
# layer  leaky_0  trainable:  False
# layer  max_1  trainable:  False
# layer  convn_2  trainable:  False
# layer  BN_2  trainable:  False
# layer  leaky_2  trainable:  False
# layer  max_3  trainable:  False
# layer  convn_4  trainable:  False
# layer  BN_4  trainable:  False
# layer  leaky_4  trainable:  False
# layer  max_5  trainable:  False
# layer  convn_6  trainable:  False
# layer  BN_6  trainable:  False
# layer  leaky_6  trainable:  False
# layer  max_7  trainable:  False
# layer  convn_8  trainable:  False
# layer  BN_8  trainable:  False
# layer  leaky_8  trainable:  False
# layer  max_9  trainable:  False
# layer  convn_10  trainable:  False
# layer  BN_10  trainable:  False
# layer  leaky_10  trainable:  False
# layer  max_11  trainable:  False
# layer  convn_12  trainable:  False
# layer  BN_12  trainable:  False
# layer  leaky_12  trainable:  False
# layer  convn_13  trainable:  True
# layer  BN_13  trainable:  True
# layer  leaky_13  trainable:  True
# layer  convn_18  trainable:  True
# layer  BN_18  trainable:  True
# layer  leaky_18  trainable:  True
# layer  upsamp_19  trainable:  True
# layer  concatenate_20  trainable:  True
# layer  convn_14  trainable:  True
# layer  convn_21  trainable:  True
# layer  BN_14  trainable:  True
# layer  BN_21  trainable:  True
# layer  leaky_14  trainable:  True
# layer  leaky_21  trainable:  True
# layer  convn_15  trainable:  True
# layer  convn_22  trainable:  True
# layer  BN_15  trainable:  True
# layer  BN_22  trainable:  True

# %%
def read_labels(labels_path):
    with open(labels_path) as f:
        labels = f.readlines()
    labels = [c.strip() for c in labels]
    return labels

# %%
# Load the labels
labels = read_labels("models/yolo/coco_classes.txt")
print(labels)
print("nb labels: ",len(labels))
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
# nb labels:  80

# %%
NETWORK_W        = 416
NETWORK_H        = 416
NB_BOX           = 3
NB_CLASS         = len(labels)
OBJ_THRESHOLD    = 0.3
NMS_THRESHOLD    = 0.3
grids = [(13,13), (26,26)]
anchors = [[81,82,  135,169,  344,319], [10,14,  23,27,  37,58]]
scales_x_y = [1.0, 1.0]

NO_OBJECT_SCALE  = 1.0
OBJECT_SCALE     = 5.0
COORD_SCALE      = 1.0
CLASS_SCALE      = 1.0

BATCH_SIZE       = 32
TRUE_BOX_BUFFER  = 50

# %%
def _interval_overlap(interval_a, interval_b):
    x1, x2 = interval_a
    x3, x4 = interval_b
    if x3 < x1:
        if x4 < x1:
            return 0
        else:
            return min(x2,x4) - x1
    else:
        if x2 < x3:
            return 0
        else:
            return min(x2,x4) - x3
     
        

def bbox_iou(box1, box2):
    intersect_w = _interval_overlap([box1.xmin, box1.xmax], [box2.xmin, box2.xmax])
    intersect_h = _interval_overlap([box1.ymin, box1.ymax], [box2.ymin, box2.ymax])
    
    intersect = intersect_w * intersect_h
    
    w1, h1 = box1.xmax-box1.xmin, box1.ymax-box1.ymin
    w2, h2 = box2.xmax-box2.xmin, box2.ymax-box2.ymin
    
    union = w1*h1 + w2*h2 - intersect
    
    return float(intersect) / union


class BoundBox:
    def __init__(self, xmin, ymin, xmax, ymax, objness = None, classes = None):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax
        self.objness = objness
        self.classes = classes
        self.label = -1
        self.score = -1
 
    def get_label(self):
        if self.label == -1:
            self.label = np.argmax(self.classes)
 
        return self.label
 
    def get_score(self):
        if self.score == -1:
            self.score = self.classes[self.get_label()]
 
        return self.score

# %%
import xml.etree.ElementTree as ET
import pickle
import os
from os import listdir, getcwd
from os.path import join

def convert(image_wh, box, grid_w, grid_h, Boxanchor, yolo_id):
    dw = image_wh[0]/ grid_w
    dh = image_wh[1]/ grid_h
    center_x = (box[0] + box[1])/2.0
    center_x = center_x / dw
    center_y = (box[2] + box[3])/2.0
    center_y = center_y / dh
    
    grid_x = int(np.floor(center_x))
    grid_y = int(np.floor(center_y))
    
    if grid_x < grid_w and grid_y < grid_h:
        w = (box[1] - box[0]) / dw
        h = (box[3] - box[2]) / dh
        
        # find the anchor that best predicts this box
        best_anchor = -1
        max_iou     = -1
    
        shifted_box = BoundBox(0,0,w,h)
    
        for i in range(len(anchors[yolo_id])//2):
            iou    = bbox_iou(shifted_box, Boxanchor[i])                   
            if max_iou < iou:
                best_anchor = i
                max_iou     = iou
    
        return (center_x,center_y,w,h,grid_x,grid_y,best_anchor)
    
    else: # not compatible with the grid size
        return (0,0,0,0,0,0,-1)
    

def convert_annotation(year, image_set, image_id, grid_w, grid_h, Boxanchor, yolo_id, VOC_path):
    in_file = open(VOC_path+'VOC%s\\Annotations\\%s.xml'%(year, image_id))
    out_file = open('VOCYoloV3Tiny\\VOC%s_%s\\tiny_labels_%s\\%s.txt'%(year, image_set, yolo_id, image_id), 'w')
    tree=ET.parse(in_file)
    root = tree.getroot()
    size = root.find('size')
    image_w = int(size.find('width').text)
    image_h = int(size.find('height').text)

    for obj in root.iter('object'):
        difficult = obj.find('difficult').text
        cls = obj.find('name').text
        if cls not in labels or int(difficult)==1:
            continue
        cls_id = labels.index(cls)
        
        xmlbox = obj.find('bndbox')
        b = (float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text))
        bb = convert((image_w,image_h), b, grid_w, grid_h, Boxanchor, yolo_id)
        
        if bb[-1] != -1:
            out_file.write(str(cls_id) + " " + " ".join([str(a) for a in bb]) + '\n')


def build_label_files (year, image_set, VOC_path):
    yolo_id = 0
    
    for grid_w, grid_h in grids:
        print("grid :",grid_w, grid_h)

        Boxanchor= [BoundBox(0, 0, anchors[yolo_id][2*i], anchors[yolo_id][2*i+1]) for i in range(int(len(anchors[yolo_id])//2))]
       
        if not os.path.exists('VOCYoloV3Tiny\\VOC%s_%s\\tiny_labels_%s\\' %(year, image_set, yolo_id)):
            os.makedirs('VOCYoloV3Tiny\\VOC%s_%s\\tiny_labels_%s\\' %(year, image_set, yolo_id))
        
        image_ids = open(VOC_path+'VOC%s\\ImageSets\\Main\\%s.txt'%(year, image_set)).read().strip().split()

        for image_id in image_ids:
            convert_annotation(year, image_set, image_id, grid_w, grid_h, Boxanchor, yolo_id, VOC_path)
            
        yolo_id+=1
    return

# %%
# Build the label files for training
VOC_path = '..\\train\\VOCdevkit\\'
build_label_files ('2012', 'train', VOC_path)
# Out:
# grid : 13 13
# grid : 26 26

# %%
# Build the label files for validation
build_label_files ('2012', 'val', VOC_path)
# Out:
# grid : 13 13
# grid : 26 26

# %%
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

# load and prepare an image
def load_image_pixels(filename, shape):
    # load the image to get its shape
    image = load_img(filename)
    width, height = image.size
    # load the image with the required size
    image = load_img(filename, interpolation = 'bilinear', target_size=shape)
    # convert to numpy array
    image = img_to_array(image)
    # scale pixel values to [0, 1]
    image = image.astype('float32')
    image /= 255.0

    # add a dimension so that we have one sample
    image = expand_dims(image, 0)
    
    return image, width, height

# %%
def build_train (year, image_set, nb_train, VOC_path):
 
    train_x  = np.zeros ((nb_train, NETWORK_H, NETWORK_W, 3), dtype=np.float32)
    train_y0 = np.zeros ((nb_train, grids[0][1], grids[0][0], NB_BOX,(4+1+NB_CLASS)), dtype=np.float32)
    train_y1 = np.zeros ((nb_train, grids[1][1], grids[1][0], NB_BOX,(4+1+NB_CLASS)), dtype=np.float32)
    bc = 0 
        
    image_ids = open(VOC_path+'VOC%s\\ImageSets\\Main\\%s.txt'%(year, image_set)).read().strip().split()

    
    for image_id in image_ids:        
        # Pre-process the image train_x
        img_filename = VOC_path+'VOC%s\\JPEGImages\\%s.jpg'%(year, image_id)
        image, image_w, image_h = load_image_pixels(img_filename, (NETWORK_W, NETWORK_H))
        train_x[bc,:,:,:] = image
        
        # build true predict train_y0 and box b0
        labels_file = open('VOCYoloV3Tiny\\VOC%s_%s\\tiny_labels_0\\%s.txt'%(year, image_set, image_id), 'r')
        
        rec = np.fromfile(labels_file, dtype=np.float32, sep = " ")
        for i in range(len(rec)//8):
            classid,x,y,w,h,grid_x,grid_y,best_anchor = rec[8*i:8*(i+1)]
            train_y0[bc, int(grid_y),int(grid_x),int(best_anchor), 0:4] = x,y,w,h
            train_y0[bc, int(grid_y),int(grid_x),int(best_anchor), 4] = 1.
            train_y0[bc, int(grid_y),int(grid_x),int(best_anchor), 5+ int(classid)] = 0.9 #Class label smoothing, use 0.9 instead of 1.0 in order to mitigate overfitting.
            
        # build true predict train_y1 and box b1
        labels_file = open('VOCYoloV3Tiny\\VOC%s_%s\\tiny_labels_1\\%s.txt'%(year, image_set, image_id), 'r')
        
        rec = np.fromfile(labels_file, dtype=np.float32, sep = " ")
        true_box_index = 0
        for i in range(len(rec)//8):
            classid,x,y,w,h,grid_x,grid_y,best_anchor = rec[8*i:8*(i+1)]
            train_y1[bc, int(grid_y),int(grid_x),int(best_anchor), 0:4] = x,y,w,h
            train_y1[bc, int(grid_y),int(grid_x),int(best_anchor), 4] = 1.
            train_y1[bc, int(grid_y),int(grid_x),int(best_anchor), 5+ int(classid)] = 0.9 #Class label smoothing, use 0.9 instead of 1.0 in order to mitigate overfitting.
             
        bc+=1
        if bc == nb_train:
            break
            
    return(train_x,  [train_y0,train_y1])

# %%
# Compute the data for training
VOC_path = '..\\train\\VOCdevkit\\'
nb_data_for_training= 640
train_x, train_y = build_train('2012', 'train', (nb_data_for_training//BATCH_SIZE)*BATCH_SIZE, VOC_path)

# %%
# Compute the data for validation
nb_data_for_validation= 320
val_x, val_y = build_train('2012', 'val', (nb_data_for_validation//BATCH_SIZE)*BATCH_SIZE, VOC_path)

# %%
def custom_loss(y_true, y_pred):
   
    print("TensorFlow version: {}".format(tf.__version__))
    print("Eager execution: {}".format(tf.executing_eagerly()))
    print("Keras version: {}".format(tf.keras.__version__))
   
    print(y_pred.shape)
    grid_h, grid_w = y_pred.shape[1:3] 
    print ("grid_h, grid_w",grid_h, grid_w)
    
    if grid_h == 13:
        anchor = anchors[0]
    else:    
        anchor = anchors[1]     
        
    mask_shape = tf.shape(y_true)[:4]
    print ("mask_shape",mask_shape)

    
    cell_x = tf.cast((tf.reshape(tf.tile(tf.range(grid_w), [grid_h]), (1, grid_h, grid_w, 1, 1))),dtype=tf.float32)
    cell_y = tf.transpose(cell_x, (0,2,1,3,4))
    cell_grid = tf.tile(tf.concat([cell_x,cell_y], -1), [BATCH_SIZE, 1, 1, NB_BOX, 1])
    
    
    ######  prediction
    y_pred = tf.reshape(y_pred, (BATCH_SIZE, grid_h, grid_w, NB_BOX, NB_CLASS+5))

    ### adjust x and y  
    pred_box_xy = tf.sigmoid(y_pred[..., :2]) # x, y)
    pred_box_xy = pred_box_xy + cell_grid
    
    ### adjust w and h
    pred_box_wh = tf.exp(y_pred[..., 2:4]) * np.reshape(anchor, [1,1,1,NB_BOX,2])
    
    ### adjust objectness
    pred_box_obj = tf.sigmoid(y_pred[..., 4])
    
    ### adjust class probabilities
    pred_box_class = tf.sigmoid(y_pred[..., 5:])
    
    
    ######  true
    y_true = tf.reshape(y_true, (BATCH_SIZE, grid_h, grid_w, NB_BOX, NB_CLASS+5))
    print ("y_true", y_true.shape)

    ### adjust x and y  
    true_box_xy = y_true[..., :2] # x, y
    
    ### adjust w and h
    true_box_wh = y_true[..., 2:4]
    
    ### adjust objectness
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half

    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half       

    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas + 1e-10
    iou_scores  = tf.truediv(intersect_areas, union_areas)
   
    true_box_obj = iou_scores * y_true[..., 4]
    
    ### adjust class probabilities
    true_box_class = tf.argmax(y_true[..., 5:], -1)

    
    
    ######  coefficients   
   
    ### coordinate mask: simply the position of the ground truth boxes (the predictors)
    ### is 1 when there is an object in the cell i, else 0.
    coord_mask = tf.zeros(mask_shape)
    coord_mask = tf.expand_dims(y_true[..., 4], axis=-1) * COORD_SCALE
    print("sum coord_mask",tf.reduce_sum(coord_mask))
    
    ### objectness mask: penelize predictors + penalize boxes with low IOU
    # penalize the confidence of the boxes, which have IOU with some ground truth box < 0.6
    for i in range(BATCH_SIZE):
        bd = y_true[i,:,:,:,:4]
        nozero = tf.not_equal(bd, tf.zeros((grid_h, grid_w, NB_BOX, 4)))
        bdd = tf.boolean_mask(bd, nozero)
        s=tf.squeeze(tf.size(bdd)//4)
        c= tf.zeros((50-s,4))
        bdd=tf.reshape(bdd, (s,4))
        bdd = tf.concat([bdd,c],axis=0)
        bdd = tf.expand_dims(bdd,0)
        bdd = tf.expand_dims(bdd,0)
        bdd = tf.expand_dims(bdd,0)
        bdd = tf.expand_dims(bdd,0)
        if (i==0):
            true_boxes =bdd
        else:
            true_boxes = tf.concat([true_boxes,bdd], axis=0)  
    
    true_xy = true_boxes[..., 0:2]
    true_wh = true_boxes[..., 2:4]
    true_wh_half = true_wh / 2.
    true_mins    = true_xy - true_wh_half
    true_maxes   = true_xy + true_wh_half
    
    pred_xy = tf.expand_dims(pred_box_xy, 4)
    pred_wh = tf.expand_dims(pred_box_wh, 4)
    
    pred_wh_half = pred_wh / 2.
    pred_mins    = pred_xy - pred_wh_half
    pred_maxes   = pred_xy + pred_wh_half    
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_wh[..., 0] * true_wh[..., 1]
    pred_areas = pred_wh[..., 0] * pred_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)

    best_ious = tf.reduce_max(iou_scores, axis=4)
    print("best_ious", tf.reduce_max(best_ious))
    
    obj_mask = tf.zeros(mask_shape)
    obj_mask = tf.cast((best_ious < 0.6),dtype=tf.float32) * (1 - y_true[..., 4]) * NO_OBJECT_SCALE
    obj_mask = obj_mask + y_true[..., 4] * OBJECT_SCALE

    print("sum obj_mask",tf.reduce_sum(obj_mask))
    
    ### class mask: simply the position of the ground truth boxes (the predictors)
    ### is 1 when there is a particular class is predicted, else 0.
    class_mask = tf.zeros(mask_shape)
    class_weights = np.ones(NB_CLASS, dtype='float32')
    class_mask = y_true[..., 4] * tf.gather(class_weights, true_box_class) * CLASS_SCALE
    print("sum class_mask",tf.reduce_sum(class_mask))
    
    nb_coord_box = tf.reduce_sum(tf.cast((coord_mask > 0.0),dtype=tf.float32))
    nb_obj_box  = tf.reduce_sum(tf.cast((obj_mask  > 0.0),dtype=tf.float32))
    nb_class_box = tf.reduce_sum(tf.cast((class_mask > 0.0),dtype=tf.float32))
    print("nb_coord_box",nb_coord_box)
    print("nb_obj_box",nb_obj_box)
    print("nb_class_box",nb_class_box) 
      
    ### loss
    loss_xy    = tf.reduce_sum(coord_mask * tf.square(true_box_xy - pred_box_xy)) / (nb_coord_box + 1e-6) / 2.
    loss_wh    = tf.reduce_sum(coord_mask * tf.square(tf.sqrt(tf.abs(true_box_wh)) - tf.sqrt(tf.abs(pred_box_wh)))) / (nb_coord_box + 1e-6) / 2.
    loss_obj   = tf.reduce_sum(obj_mask * tf.square(true_box_obj-pred_box_obj)) / (nb_obj_box + 1e-6) / 2.
    loss_class = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=true_box_class, logits=pred_box_class)
    loss_class = tf.reduce_sum(class_mask * loss_class) / (nb_class_box + 1e-6)

    print("loss_xy",loss_xy.shape)
    print("sum loss_xy",tf.reduce_sum(loss_xy))
    
    print("loss_wh",loss_wh.shape)
    print("sum loss_wh",tf.reduce_sum(loss_wh))
    
    print("loss_obj",loss_obj.shape)
    print("sum loss_obj",tf.reduce_sum(loss_obj))
        
    print("loss_class",loss_class.shape)
    print("sum loss_class",tf.reduce_sum(loss_class))
    
    loss = loss_xy + loss_wh + loss_obj + loss_class
    print("loss",loss.shape)
    print()
    return loss

# %%
# Choose the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

#optimizer = tf.keras.optimizers.SGD(lr=1e-4, decay=0.0005, momentum=0.9)
#optimizer = tf.keras.optimizers.SGD.RMSprop(lr=1e-4, rho=0.9, epsilon=1e-08, decay=0.0)

# %%
# Compile the model using the custom loss function defined above
yolo_model.compile(loss=custom_loss, optimizer=optimizer)
# Out:
# TensorFlow version: 2.1.0
# Eager execution: False
# Keras version: 2.2.4-tf
# (None, 13, 13, 255)
# grid_h, grid_w 13 13
# mask_shape Tensor("loss/BN_15_loss/custom_loss/strided_slice:0", shape=(4,), dtype=int32)
# y_true (32, 13, 13, 3, 85)
# sum coord_mask Tensor("loss/BN_15_loss/custom_loss/Sum:0", shape=(), dtype=float32)
# best_ious Tensor("loss/BN_15_loss/custom_loss/Max_1:0", shape=(), dtype=float32)
# sum obj_mask Tensor("loss/BN_15_loss/custom_loss/Sum_1:0", shape=(), dtype=float32)
# sum class_mask Tensor("loss/BN_15_loss/custom_loss/Sum_2:0", shape=(), dtype=float32)
# nb_coord_box Tensor("loss/BN_15_loss/custom_loss/Sum_3:0", shape=(), dtype=float32)
# nb_obj_box Tensor("loss/BN_15_loss/custom_loss/Sum_4:0", shape=(), dtype=float32)
# nb_class_box Tensor("loss/BN_15_loss/custom_loss/Sum_5:0", shape=(), dtype=float32)
# loss_xy ()
# sum loss_xy Tensor("loss/BN_15_loss/custom_loss/Sum_10:0", shape=(), dtype=float32)
# loss_wh ()
# sum loss_wh Tensor("loss/BN_15_loss/custom_loss/Sum_11:0", shape=(), dtype=float32)
# loss_obj ()
# sum loss_obj Tensor("loss/BN_15_loss/custom_loss/Sum_12:0", shape=(), dtype=float32)
# loss_class ()
# sum loss_class Tensor("loss/BN_15_loss/custom_loss/Sum_13:0", shape=(), dtype=float32)
# loss ()
#
# TensorFlow version: 2.1.0
# Eager execution: False
# Keras version: 2.2.4-tf
# (None, 26, 26, 255)
# grid_h, grid_w 26 26
# mask_shape Tensor("loss/BN_22_loss/custom_loss/strided_slice:0", shape=(4,), dtype=int32)
# y_true (32, 26, 26, 3, 85)
# sum coord_mask Tensor("loss/BN_22_loss/custom_loss/Sum:0", shape=(), dtype=float32)
# best_ious Tensor("loss/BN_22_loss/custom_loss/Max_1:0", shape=(), dtype=float32)
# sum obj_mask Tensor("loss/BN_22_loss/custom_loss/Sum_1:0", shape=(), dtype=float32)
# sum class_mask Tensor("loss/BN_22_loss/custom_loss/Sum_2:0", shape=(), dtype=float32)
# nb_coord_box Tensor("loss/BN_22_loss/custom_loss/Sum_3:0", shape=(), dtype=float32)
# nb_obj_box Tensor("loss/BN_22_loss/custom_loss/Sum_4:0", shape=(), dtype=float32)
# nb_class_box Tensor("loss/BN_22_loss/custom_loss/Sum_5:0", shape=(), dtype=float32)
# loss_xy ()
# sum loss_xy Tensor("loss/BN_22_loss/custom_loss/Sum_10:0", shape=(), dtype=float32)
# loss_wh ()
# sum loss_wh Tensor("loss/BN_22_loss/custom_loss/Sum_11:0", shape=(), dtype=float32)
# loss_obj ()
# sum loss_obj Tensor("loss/BN_22_loss/custom_loss/Sum_12:0", shape=(), dtype=float32)
# loss_class ()
# sum loss_class Tensor("loss/BN_22_loss/custom_loss/Sum_13:0", shape=(), dtype=float32)
# loss ()

# %%
class CustomCallback(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        print("Starting train")

    def on_train_end(self, logs=None):
        print("Stop train")
        
    def on_epoch_begin(self, epoch, logs=None):
        print("--Start epoch {}".format(epoch))

    def on_epoch_end(self, epoch, logs=None):
        print("--End epoch {}, the average training loss is {:7.2f}, testing loss is {:7.2f}".format(epoch, logs["loss"], logs["val_loss"]))        
        
    def on_train_batch_begin(self, batch, logs=None):
        print("---Start training batch {}, size {}".format(batch,logs["size"]))
        
    def on_train_batch_end(self, batch, logs=None):
        print("---End training batch {}, total loss is {:7.2f}, loss (13*13) is {:7.2f}, loss (26*26) is {:7.2f}"
              .format(batch, logs["loss"],logs["BN_15_loss"],logs["BN_22_loss"]))      

    def on_test_begin(self, logs=None):
        print("-Start testing")
        
    def on_test_end(self, logs=None):
        print("-Stop testing")
    
    def on_test_batch_begin(self, batch, logs=None):
        print("---Start testing batch {}, size {}".format(batch,logs["size"]))
        
    def on_test_batch_end(self, batch, logs=None):
        print("---End testing batch {}, total loss is {:7.2f}, loss (13*13) is {:7.2f}, loss (26*26) is {:7.2f}"
              .format(batch, logs["loss"],logs["BN_15_loss"],logs["BN_22_loss"]))

# %%
# Fit the model including validation data
import datetime
start = datetime.datetime.now()

EScallback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)

history = yolo_model.fit(x=train_x, y=train_y, validation_data = (val_x,val_y), epochs= 10,batch_size =BATCH_SIZE, verbose=2, callbacks=[CustomCallback(),EScallback])

elapsed = datetime.datetime.now()-start
print("elapsed seconds: ",elapsed.seconds)
# Out:
# Train on 640 samples, validate on 320 samples
# Starting train
# Epoch 1/10
# --Start epoch 0
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is  125.86, loss (13*13) is  112.48, loss (26*26) is   13.37
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   56.42, loss (13*13) is   80.95, loss (26*26) is   10.18
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   43.48, loss (13*13) is   66.16, loss (26*26) is    9.09
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   35.70, loss (13*13) is   56.89, loss (26*26) is    8.47
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   39.74, loss (13*13) is   52.13, loss (26*26) is    8.11
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   28.58, loss (13*13) is   47.25, loss (26*26) is    7.72
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   23.99, loss (13*13) is   43.12, loss (26*26) is    7.42
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   25.27, loss (13*13) is   40.18, loss (26*26) is    7.20
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   26.14, loss (13*13) is   38.00, loss (26*26) is    7.02
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   22.31, loss (13*13) is   35.89, loss (26*26) is    6.86
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   32.33, loss (13*13) is   35.03, loss (26*26) is    6.77
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   23.65, loss (13*13) is   33.61, loss (26*26) is    6.68
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   27.21, loss (13*13) is   32.70, loss (26*26) is    6.58
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   32.21, loss (13*13) is   32.28, loss (26*26) is    6.50
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   20.14, loss (13*13) is   31.11, loss (26*26) is    6.43
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   22.00, loss (13*13) is   30.20, loss (26*26) is    6.36
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   22.35, loss (13*13) is   29.40, loss (26*26) is    6.33
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   20.44, loss (13*13) is   28.62, loss (26*26) is    6.26
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   26.39, loss (13*13) is   28.22, loss (26*26) is    6.21
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   17.83, loss (13*13) is   27.45, loss (26*26) is    6.16
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   44.80, loss (13*13) is   37.53, loss (26*26) is    7.28
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   47.98, loss (13*13) is   39.31, loss (26*26) is    7.08
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is 1373.00, loss (13*13) is  480.65, loss (26*26) is    7.94
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   27.27, loss (13*13) is  365.83, loss (26*26) is    7.43
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   23.04, loss (13*13) is  295.63, loss (26*26) is    7.59
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   15.52, loss (13*13) is  247.97, loss (26*26) is    7.29
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   19.38, loss (13*13) is  214.53, loss (26*26) is    7.04
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   17.85, loss (13*13) is  189.25, loss (26*26) is    6.85
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   16.68, loss (13*13) is  169.40, loss (26*26) is    6.76
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   66.65, loss (13*13) is  158.58, loss (26*26) is    6.64
# -Stop testing
#  - 317s - loss: 33.6023 - BN_15_loss: 27.4460 - BN_22_loss: 6.1562 - val_loss: 165.2142 - val_BN_15_loss: 158.5777 - val_BN_22_loss: 6.6365
# --End epoch 0, the average training loss is   33.60, testing loss is  165.21
# Epoch 2/10
# --Start epoch 1
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   18.23, loss (13*13) is   13.38, loss (26*26) is    4.85
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   24.01, loss (13*13) is   16.11, loss (26*26) is    5.02
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   20.77, loss (13*13) is   16.03, loss (26*26) is    4.97
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   21.97, loss (13*13) is   16.25, loss (26*26) is    4.99
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   22.00, loss (13*13) is   16.39, loss (26*26) is    5.00
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   19.83, loss (13*13) is   16.16, loss (26*26) is    4.98
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   16.97, loss (13*13) is   15.61, loss (26*26) is    4.93
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   19.86, loss (13*13) is   15.55, loss (26*26) is    4.91
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   17.01, loss (13*13) is   15.19, loss (26*26) is    4.89
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   18.67, loss (13*13) is   15.05, loss (26*26) is    4.88
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   20.59, loss (13*13) is   15.12, loss (26*26) is    4.88
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   19.69, loss (13*13) is   15.11, loss (26*26) is    4.86
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   17.13, loss (13*13) is   14.90, loss (26*26) is    4.85
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   18.10, loss (13*13) is   14.79, loss (26*26) is    4.84
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   23.18, loss (13*13) is   15.04, loss (26*26) is    4.83
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   15.62, loss (13*13) is   14.80, loss (26*26) is    4.81
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   17.79, loss (13*13) is   14.70, loss (26*26) is    4.80
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   17.45, loss (13*13) is   14.60, loss (26*26) is    4.78
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   17.42, loss (13*13) is   14.51, loss (26*26) is    4.77
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   17.61, loss (13*13) is   14.44, loss (26*26) is    4.75
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   31.95, loss (13*13) is   26.34, loss (26*26) is    5.60
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   39.10, loss (13*13) is   29.86, loss (26*26) is    5.66
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is  799.89, loss (13*13) is  283.67, loss (26*26) is    6.64
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   63.45, loss (13*13) is  227.27, loss (26*26) is    6.32
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   25.82, loss (13*13) is  185.56, loss (26*26) is    6.48
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   13.44, loss (13*13) is  156.04, loss (26*26) is    6.24
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   22.18, loss (13*13) is  136.19, loss (26*26) is    6.07
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   17.76, loss (13*13) is  120.76, loss (26*26) is    5.94
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   14.10, loss (13*13) is  108.37, loss (26*26) is    5.82
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   78.55, loss (13*13) is  104.86, loss (26*26) is    5.76
# -Stop testing
#  - 174s - loss: 19.1965 - BN_15_loss: 14.4417 - BN_22_loss: 4.7548 - val_loss: 110.6236 - val_BN_15_loss: 104.8619 - val_BN_22_loss: 5.7617
# --End epoch 1, the average training loss is   19.20, testing loss is  110.62
# Epoch 3/10
# --Start epoch 2
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   16.36, loss (13*13) is   11.81, loss (26*26) is    4.55
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   14.57, loss (13*13) is   10.94, loss (26*26) is    4.52
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   17.97, loss (13*13) is   11.81, loss (26*26) is    4.49
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   16.67, loss (13*13) is   11.90, loss (26*26) is    4.50
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   15.82, loss (13*13) is   11.78, loss (26*26) is    4.50
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   19.51, loss (13*13) is   12.30, loss (26*26) is    4.52
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   16.07, loss (13*13) is   12.20, loss (26*26) is    4.51
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   17.54, loss (13*13) is   12.29, loss (26*26) is    4.52
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   17.32, loss (13*13) is   12.36, loss (26*26) is    4.51
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   14.77, loss (13*13) is   12.16, loss (26*26) is    4.50
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   16.85, loss (13*13) is   12.17, loss (26*26) is    4.50
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   15.67, loss (13*13) is   12.10, loss (26*26) is    4.49
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   16.35, loss (13*13) is   12.09, loss (26*26) is    4.49
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   13.62, loss (13*13) is   11.89, loss (26*26) is    4.48
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   16.85, loss (13*13) is   11.92, loss (26*26) is    4.48
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   15.74, loss (13*13) is   11.88, loss (26*26) is    4.47
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   16.67, loss (13*13) is   11.89, loss (26*26) is    4.48
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   14.60, loss (13*13) is   11.80, loss (26*26) is    4.47
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   19.16, loss (13*13) is   11.96, loss (26*26) is    4.47
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   15.76, loss (13*13) is   11.93, loss (26*26) is    4.47
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   24.32, loss (13*13) is   19.16, loss (26*26) is    5.16
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   21.51, loss (13*13) is   17.71, loss (26*26) is    5.21
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is  247.32, loss (13*13) is   91.95, loss (26*26) is    5.77
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is  144.53, loss (13*13) is  103.84, loss (26*26) is    5.58
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   15.58, loss (13*13) is   85.00, loss (26*26) is    5.65
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   12.53, loss (13*13) is   72.13, loss (26*26) is    5.51
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   16.98, loss (13*13) is   63.53, loss (26*26) is    5.43
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   17.68, loss (13*13) is   57.18, loss (26*26) is    5.37
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   13.24, loss (13*13) is   51.77, loss (26*26) is    5.31
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   40.46, loss (13*13) is   50.14, loss (26*26) is    5.28
# -Stop testing
#  - 151s - loss: 16.3928 - BN_15_loss: 11.9270 - BN_22_loss: 4.4658 - val_loss: 55.4144 - val_BN_15_loss: 50.1357 - val_BN_22_loss: 5.2787
# --End epoch 2, the average training loss is   16.39, testing loss is   55.41
# Epoch 4/10
# --Start epoch 3
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   17.07, loss (13*13) is   12.76, loss (26*26) is    4.31
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   13.88, loss (13*13) is   11.15, loss (26*26) is    4.32
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   12.92, loss (13*13) is   10.33, loss (26*26) is    4.29
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   14.10, loss (13*13) is   10.19, loss (26*26) is    4.30
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   13.78, loss (13*13) is   10.06, loss (26*26) is    4.29
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   15.69, loss (13*13) is   10.28, loss (26*26) is    4.29
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   14.59, loss (13*13) is   10.29, loss (26*26) is    4.28
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   11.26, loss (13*13) is    9.89, loss (26*26) is    4.27
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   14.80, loss (13*13) is    9.95, loss (26*26) is    4.28
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   13.57, loss (13*13) is    9.88, loss (26*26) is    4.28
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   13.93, loss (13*13) is    9.86, loss (26*26) is    4.28
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   14.42, loss (13*13) is    9.89, loss (26*26) is    4.28
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   17.50, loss (13*13) is   10.13, loss (26*26) is    4.29
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   13.41, loss (13*13) is   10.06, loss (26*26) is    4.30
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   15.49, loss (13*13) is   10.13, loss (26*26) is    4.30
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   15.40, loss (13*13) is   10.19, loss (26*26) is    4.30
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   12.99, loss (13*13) is   10.11, loss (26*26) is    4.29
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   14.42, loss (13*13) is   10.11, loss (26*26) is    4.29
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   12.89, loss (13*13) is   10.03, loss (26*26) is    4.30
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   12.86, loss (13*13) is    9.95, loss (26*26) is    4.29
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   20.43, loss (13*13) is   15.41, loss (26*26) is    5.02
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   17.39, loss (13*13) is   13.75, loss (26*26) is    5.15
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is  102.05, loss (13*13) is   40.98, loss (26*26) is    5.64
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   98.07, loss (13*13) is   53.92, loss (26*26) is    5.57
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   15.16, loss (13*13) is   44.95, loss (26*26) is    5.67
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   12.84, loss (13*13) is   38.80, loss (26*26) is    5.52
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   19.77, loss (13*13) is   35.33, loss (26*26) is    5.48
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   15.85, loss (13*13) is   32.20, loss (26*26) is    5.49
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   12.48, loss (13*13) is   29.44, loss (26*26) is    5.45
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   27.25, loss (13*13) is   28.71, loss (26*26) is    5.42
# -Stop testing
#  - 136s - loss: 14.2483 - BN_15_loss: 9.9534 - BN_22_loss: 4.2949 - val_loss: 34.1274 - val_BN_15_loss: 28.7123 - val_BN_22_loss: 5.4151
# --End epoch 3, the average training loss is   14.25, testing loss is   34.13
# Epoch 5/10
# --Start epoch 4
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   13.70, loss (13*13) is    9.50, loss (26*26) is    4.20
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   12.10, loss (13*13) is    8.72, loss (26*26) is    4.19
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   13.22, loss (13*13) is    8.80, loss (26*26) is    4.21
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   12.10, loss (13*13) is    8.60, loss (26*26) is    4.18
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   12.96, loss (13*13) is    8.62, loss (26*26) is    4.20
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   12.81, loss (13*13) is    8.62, loss (26*26) is    4.19
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   12.07, loss (13*13) is    8.52, loss (26*26) is    4.19
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   12.64, loss (13*13) is    8.51, loss (26*26) is    4.19
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   13.91, loss (13*13) is    8.66, loss (26*26) is    4.18
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   12.80, loss (13*13) is    8.66, loss (26*26) is    4.18
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   11.73, loss (13*13) is    8.55, loss (26*26) is    4.18
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   12.03, loss (13*13) is    8.50, loss (26*26) is    4.18
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   14.19, loss (13*13) is    8.61, loss (26*26) is    4.18
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   13.97, loss (13*13) is    8.70, loss (26*26) is    4.18
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   13.40, loss (13*13) is    8.73, loss (26*26) is    4.18
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   14.28, loss (13*13) is    8.81, loss (26*26) is    4.19
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   12.84, loss (13*13) is    8.80, loss (26*26) is    4.19
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   14.08, loss (13*13) is    8.86, loss (26*26) is    4.19
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   13.83, loss (13*13) is    8.90, loss (26*26) is    4.18
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   13.20, loss (13*13) is    8.91, loss (26*26) is    4.18
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   18.05, loss (13*13) is   13.14, loss (26*26) is    4.92
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   16.37, loss (13*13) is   12.16, loss (26*26) is    5.05
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   63.69, loss (13*13) is   27.29, loss (26*26) is    5.41
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   39.86, loss (13*13) is   29.13, loss (26*26) is    5.36
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   12.49, loss (13*13) is   24.70, loss (26*26) is    5.40
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   11.61, loss (13*13) is   21.73, loss (26*26) is    5.28
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   16.20, loss (13*13) is   20.20, loss (26*26) is    5.27
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   13.39, loss (13*13) is   18.66, loss (26*26) is    5.30
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   11.61, loss (13*13) is   17.31, loss (26*26) is    5.28
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   21.41, loss (13*13) is   17.21, loss (26*26) is    5.26
# -Stop testing
#  - 140s - loss: 13.0939 - BN_15_loss: 8.9133 - BN_22_loss: 4.1806 - val_loss: 22.4683 - val_BN_15_loss: 17.2113 - val_BN_22_loss: 5.2570
# --End epoch 4, the average training loss is   13.09, testing loss is   22.47
# Epoch 6/10
# --Start epoch 5
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   11.40, loss (13*13) is    7.29, loss (26*26) is    4.11
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   12.72, loss (13*13) is    7.95, loss (26*26) is    4.12
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   12.68, loss (13*13) is    8.14, loss (26*26) is    4.13
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   12.92, loss (13*13) is    8.30, loss (26*26) is    4.13
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   12.01, loss (13*13) is    8.22, loss (26*26) is    4.12
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   11.20, loss (13*13) is    8.04, loss (26*26) is    4.11
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   11.61, loss (13*13) is    7.97, loss (26*26) is    4.11
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   13.86, loss (13*13) is    8.19, loss (26*26) is    4.11
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   11.52, loss (13*13) is    8.10, loss (26*26) is    4.12
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   12.14, loss (13*13) is    8.09, loss (26*26) is    4.11
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   11.75, loss (13*13) is    8.06, loss (26*26) is    4.11
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   11.55, loss (13*13) is    8.01, loss (26*26) is    4.10
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   10.85, loss (13*13) is    7.92, loss (26*26) is    4.10
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   10.55, loss (13*13) is    7.81, loss (26*26) is    4.10
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   11.71, loss (13*13) is    7.80, loss (26*26) is    4.10
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   13.24, loss (13*13) is    7.89, loss (26*26) is    4.10
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   14.42, loss (13*13) is    8.03, loss (26*26) is    4.10
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   10.28, loss (13*13) is    7.93, loss (26*26) is    4.09
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   11.64, loss (13*13) is    7.91, loss (26*26) is    4.09
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   13.10, loss (13*13) is    7.97, loss (26*26) is    4.09
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   18.91, loss (13*13) is   14.08, loss (26*26) is    4.84
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   13.21, loss (13*13) is   11.03, loss (26*26) is    5.03
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   37.59, loss (13*13) is   17.94, loss (26*26) is    5.30
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   45.42, loss (13*13) is   23.50, loss (26*26) is    5.28
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   12.87, loss (13*13) is   20.27, loss (26*26) is    5.33
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   11.63, loss (13*13) is   18.04, loss (26*26) is    5.23
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   14.91, loss (13*13) is   16.85, loss (26*26) is    5.23
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   13.71, loss (13*13) is   15.75, loss (26*26) is    5.28
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   11.56, loss (13*13) is   14.71, loss (26*26) is    5.27
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   16.48, loss (13*13) is   14.38, loss (26*26) is    5.25
# -Stop testing
#  - 138s - loss: 12.0568 - BN_15_loss: 7.9666 - BN_22_loss: 4.0902 - val_loss: 19.6284 - val_BN_15_loss: 14.3757 - val_BN_22_loss: 5.2527
# --End epoch 5, the average training loss is   12.06, testing loss is   19.63
# Epoch 7/10
# --Start epoch 6
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   12.13, loss (13*13) is    8.04, loss (26*26) is    4.09
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   11.28, loss (13*13) is    7.67, loss (26*26) is    4.04
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   11.09, loss (13*13) is    7.48, loss (26*26) is    4.02
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   10.84, loss (13*13) is    7.33, loss (26*26) is    4.00
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   11.23, loss (13*13) is    7.32, loss (26*26) is    4.00
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   11.32, loss (13*13) is    7.31, loss (26*26) is    4.01
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   11.62, loss (13*13) is    7.35, loss (26*26) is    4.01
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   11.08, loss (13*13) is    7.31, loss (26*26) is    4.02
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   11.03, loss (13*13) is    7.27, loss (26*26) is    4.02
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   11.62, loss (13*13) is    7.30, loss (26*26) is    4.02
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   10.89, loss (13*13) is    7.27, loss (26*26) is    4.02
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   10.00, loss (13*13) is    7.16, loss (26*26) is    4.02
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   10.63, loss (13*13) is    7.12, loss (26*26) is    4.01
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   10.10, loss (13*13) is    7.05, loss (26*26) is    4.01
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is    9.98, loss (13*13) is    6.98, loss (26*26) is    4.01
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   10.14, loss (13*13) is    6.93, loss (26*26) is    4.00
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is    9.81, loss (13*13) is    6.87, loss (26*26) is    4.00
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   10.01, loss (13*13) is    6.82, loss (26*26) is    4.00
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   10.91, loss (13*13) is    6.83, loss (26*26) is    4.00
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   10.71, loss (13*13) is    6.82, loss (26*26) is    4.00
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   18.10, loss (13*13) is   13.24, loss (26*26) is    4.86
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   13.45, loss (13*13) is   10.73, loss (26*26) is    5.05
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   48.43, loss (13*13) is   21.30, loss (26*26) is    5.36
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   32.27, loss (13*13) is   22.77, loss (26*26) is    5.29
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   12.08, loss (13*13) is   19.56, loss (26*26) is    5.31
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   11.59, loss (13*13) is   17.45, loss (26*26) is    5.21
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   14.52, loss (13*13) is   16.29, loss (26*26) is    5.20
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   12.80, loss (13*13) is   15.17, loss (26*26) is    5.23
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   10.81, loss (13*13) is   14.14, loss (26*26) is    5.20
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   16.39, loss (13*13) is   13.85, loss (26*26) is    5.19
# -Stop testing
#  - 139s - loss: 10.8218 - BN_15_loss: 6.8202 - BN_22_loss: 4.0016 - val_loss: 19.0434 - val_BN_15_loss: 13.8517 - val_BN_22_loss: 5.1917
# --End epoch 6, the average training loss is   10.82, testing loss is   19.04
# Epoch 8/10
# --Start epoch 7
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   10.06, loss (13*13) is    6.12, loss (26*26) is    3.94
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is    9.70, loss (13*13) is    5.94, loss (26*26) is    3.95
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   10.54, loss (13*13) is    6.14, loss (26*26) is    3.96
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   10.86, loss (13*13) is    6.34, loss (26*26) is    3.95
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is    9.42, loss (13*13) is    6.18, loss (26*26) is    3.94
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   10.65, loss (13*13) is    6.26, loss (26*26) is    3.95
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is    9.90, loss (13*13) is    6.22, loss (26*26) is    3.94
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is    9.88, loss (13*13) is    6.18, loss (26*26) is    3.94
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is    9.88, loss (13*13) is    6.16, loss (26*26) is    3.94
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is    9.18, loss (13*13) is    6.06, loss (26*26) is    3.95
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   10.19, loss (13*13) is    6.07, loss (26*26) is    3.95
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is    9.27, loss (13*13) is    6.01, loss (26*26) is    3.95
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is    8.90, loss (13*13) is    5.94, loss (26*26) is    3.94
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is    9.10, loss (13*13) is    5.88, loss (26*26) is    3.94
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   10.31, loss (13*13) is    5.92, loss (26*26) is    3.94
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is    9.33, loss (13*13) is    5.89, loss (26*26) is    3.94
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is    8.51, loss (13*13) is    5.82, loss (26*26) is    3.93
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is    8.94, loss (13*13) is    5.77, loss (26*26) is    3.93
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is    9.54, loss (13*13) is    5.77, loss (26*26) is    3.93
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is    9.11, loss (13*13) is    5.74, loss (26*26) is    3.92
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   17.33, loss (13*13) is   12.62, loss (26*26) is    4.71
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   13.63, loss (13*13) is   10.58, loss (26*26) is    4.90
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   36.09, loss (13*13) is   17.15, loss (26*26) is    5.21
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   19.78, loss (13*13) is   16.57, loss (26*26) is    5.14
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   13.16, loss (13*13) is   14.85, loss (26*26) is    5.15
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   12.32, loss (13*13) is   13.66, loss (26*26) is    5.06
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   15.33, loss (13*13) is   13.19, loss (26*26) is    5.05
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   13.58, loss (13*13) is   12.60, loss (26*26) is    5.05
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   10.26, loss (13*13) is   11.82, loss (26*26) is    5.01
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   15.62, loss (13*13) is   11.71, loss (26*26) is    5.00
# -Stop testing
#  - 136s - loss: 9.6641 - BN_15_loss: 5.7393 - BN_22_loss: 3.9249 - val_loss: 16.7115 - val_BN_15_loss: 11.7117 - val_BN_22_loss: 4.9998
# --End epoch 7, the average training loss is    9.66, testing loss is   16.71
# Epoch 9/10
# --Start epoch 8
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is    9.40, loss (13*13) is    5.52, loss (26*26) is    3.88
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is    8.66, loss (13*13) is    5.17, loss (26*26) is    3.86
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is    9.15, loss (13*13) is    5.21, loss (26*26) is    3.86
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is    9.12, loss (13*13) is    5.21, loss (26*26) is    3.87
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is    8.95, loss (13*13) is    5.19, loss (26*26) is    3.86
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is    8.47, loss (13*13) is    5.11, loss (26*26) is    3.85
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is    9.11, loss (13*13) is    5.13, loss (26*26) is    3.85
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is    9.79, loss (13*13) is    5.23, loss (26*26) is    3.86
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is    8.89, loss (13*13) is    5.21, loss (26*26) is    3.85
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is    9.37, loss (13*13) is    5.24, loss (26*26) is    3.85
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is    8.81, loss (13*13) is    5.21, loss (26*26) is    3.85
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is    8.38, loss (13*13) is    5.16, loss (26*26) is    3.85
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is    8.60, loss (13*13) is    5.13, loss (26*26) is    3.85
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is    8.72, loss (13*13) is    5.11, loss (26*26) is    3.85
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is    9.69, loss (13*13) is    5.16, loss (26*26) is    3.85
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is    8.95, loss (13*13) is    5.15, loss (26*26) is    3.85
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is    8.73, loss (13*13) is    5.14, loss (26*26) is    3.85
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is    8.62, loss (13*13) is    5.12, loss (26*26) is    3.85
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is    8.66, loss (13*13) is    5.10, loss (26*26) is    3.85
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is    8.28, loss (13*13) is    5.06, loss (26*26) is    3.85
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   17.62, loss (13*13) is   12.90, loss (26*26) is    4.73
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   12.36, loss (13*13) is   10.11, loss (26*26) is    4.88
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   32.26, loss (13*13) is   15.57, loss (26*26) is    5.18
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   15.53, loss (13*13) is   14.33, loss (26*26) is    5.11
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   11.94, loss (13*13) is   12.85, loss (26*26) is    5.10
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   11.45, loss (13*13) is   11.84, loss (26*26) is    5.02
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   13.59, loss (13*13) is   11.37, loss (26*26) is    5.02
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   12.47, loss (13*13) is   10.86, loss (26*26) is    5.04
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   10.24, loss (13*13) is   10.27, loss (26*26) is    5.01
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   14.24, loss (13*13) is   10.17, loss (26*26) is    5.00
# -Stop testing
#  - 140s - loss: 8.9172 - BN_15_loss: 5.0645 - BN_22_loss: 3.8528 - val_loss: 15.1698 - val_BN_15_loss: 10.1742 - val_BN_22_loss: 4.9956
# --End epoch 8, the average training loss is    8.92, testing loss is   15.17
# Epoch 10/10
# --Start epoch 9
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is    8.34, loss (13*13) is    4.54, loss (26*26) is    3.81
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is    8.67, loss (13*13) is    4.71, loss (26*26) is    3.80
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is    8.45, loss (13*13) is    4.68, loss (26*26) is    3.81
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is    8.29, loss (13*13) is    4.63, loss (26*26) is    3.81
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is    8.41, loss (13*13) is    4.63, loss (26*26) is    3.81
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is    8.24, loss (13*13) is    4.59, loss (26*26) is    3.81
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is    8.58, loss (13*13) is    4.62, loss (26*26) is    3.81
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is    8.53, loss (13*13) is    4.63, loss (26*26) is    3.81
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is    8.55, loss (13*13) is    4.65, loss (26*26) is    3.80
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is    8.33, loss (13*13) is    4.64, loss (26*26) is    3.80
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is    8.56, loss (13*13) is    4.64, loss (26*26) is    3.81
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is    8.22, loss (13*13) is    4.62, loss (26*26) is    3.81
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is    8.56, loss (13*13) is    4.64, loss (26*26) is    3.81
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is    8.53, loss (13*13) is    4.64, loss (26*26) is    3.81
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is    8.13, loss (13*13) is    4.62, loss (26*26) is    3.81
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is    8.92, loss (13*13) is    4.65, loss (26*26) is    3.81
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is    8.04, loss (13*13) is    4.62, loss (26*26) is    3.81
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is    8.61, loss (13*13) is    4.64, loss (26*26) is    3.81
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is    9.21, loss (13*13) is    4.67, loss (26*26) is    3.81
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is    8.44, loss (13*13) is    4.67, loss (26*26) is    3.81
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   16.38, loss (13*13) is   11.61, loss (26*26) is    4.76
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   14.55, loss (13*13) is   10.48, loss (26*26) is    4.98
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   33.64, loss (13*13) is   16.20, loss (26*26) is    5.33
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   15.94, loss (13*13) is   14.88, loss (26*26) is    5.25
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   14.14, loss (13*13) is   13.71, loss (26*26) is    5.22
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   11.94, loss (13*13) is   12.64, loss (26*26) is    5.12
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   16.48, loss (13*13) is   12.47, loss (26*26) is    5.11
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   12.94, loss (13*13) is   11.87, loss (26*26) is    5.13
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   10.28, loss (13*13) is   11.16, loss (26*26) is    5.09
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   16.08, loss (13*13) is   11.16, loss (26*26) is    5.08
# -Stop testing
#  - 136s - loss: 8.4817 - BN_15_loss: 4.6711 - BN_22_loss: 3.8106 - val_loss: 16.2371 - val_BN_15_loss: 11.1592 - val_BN_22_loss: 5.0779
# --End epoch 9, the average training loss is    8.48, testing loss is   16.24
# Stop train
# elapsed seconds:  1627

# %%
# plot learning curves
from matplotlib import pyplot
pyplot.title('Learning Curves')
pyplot.xlabel('Epoch')
pyplot.ylabel('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='val')
pyplot.legend()
pyplot.show()
