# %%
import io
import os

from collections import defaultdict
import tensorflow as tf
import numpy as np
from keras import backend as K
from keras.layers import Conv2D, Input, BatchNormalization, LeakyReLU, ZeroPadding2D, UpSampling2D, MaxPool2D
from keras.layers.merge import add, concatenate
from keras.models import Model
from keras.utils import get_custom_objects
from keras.layers import Activation
from tensorflow.python.platform import build_info as tf_build_info

print("TensorFlow version: {}".format(tf.__version__))
print("Eager execution: {}".format(tf.executing_eagerly()))
print("Keras version: {}".format(tf.keras.__version__))
print("Cuda version: {}".format(tf_build_info.cuda_version_number))
print("Cudnn version: {}".format(tf_build_info.cudnn_version_number))
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))



NETWORK_W          = 416
NETWORK_H          = 416


# ------------------------------------------------------------
# needs to be defined as activation class otherwise error
# AttributeError: 'Activation' object has no attribute '__name__'    
class Mish(Activation):
    
    def __init__(self, activation, **kwargs):
        super(Mish, self).__init__(activation, **kwargs)
        self.__name__ = 'mish'


def mysoftplus(x):

    mask_min = tf.cast((x<-20.0),tf.float32)
    ymin = mask_min*tf.math.exp(x)

    mask_max = tf.cast((x>20.0),tf.float32)
    ymax = mask_max*x
    
    mask= tf.cast((abs(x)<=20.0),tf.float32)
    y = mask*tf.math.log(tf.math.exp(x) + 1.0)
    
    return(ymin+ymax+y)    
        


def mish(x):
    return (x* tf.math.tanh(mysoftplus(x)))
    
   
    

get_custom_objects().update({'mish': Mish(mish)})

def _conv_block(inp, convs, skip=False):
    x = inp
    count = 0
    
    for conv in convs:
        if count == (len(convs) - 2) and skip:
            skip_connection = x
        count += 1
        
        if conv['stride'] > 1: x = ZeroPadding2D(((1,0),(1,0)), name='zerop_' + str(conv['layer_idx']))(x)  # peculiar padding as darknet prefer left and top
        
        x = Conv2D(conv['filter'], 
                   conv['kernel'], 
                   strides=conv['stride'], 
                   padding='valid' if conv['stride'] > 1 else 'same', # peculiar padding as darknet prefer left and top
                   name='convn_' + str(conv['layer_idx']) if conv['bnorm'] else 'conv_' + str(conv['layer_idx']),
                   activation='mish' if conv['activ'] == 2 else None,
                   use_bias=True)(x)

        if conv['bnorm']: x = BatchNormalization(name='BN_' + str(conv['layer_idx']))(x)          
       
        if conv['activ'] == 1: x = LeakyReLU(alpha=0.1, name='leaky_' + str(conv['layer_idx']))(x)
            
    return add([skip_connection, x],  name='add_' + str(conv['layer_idx']+1)) if skip else x

def make_yolov3_tiny_model():
        
    input_image = Input(shape=(NETWORK_H, NETWORK_W, 3), name='input_0')

    # Layer  0
    x = _conv_block(input_image, [{'filter': 16, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 0}])
    
    # Layer  1
    x = MaxPool2D(pool_size=(2, 2), strides=2, padding='same', name = 'max_1')(x)
    
    # Layer  2
    x = _conv_block(x, [{'filter': 32, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 2}])
  
    # Layer  3
    x = MaxPool2D(pool_size=(2, 2), strides=2, padding='same', name = 'max_3')(x)
    
    # Layer  4
    x = _conv_block(x, [{'filter': 64, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 4}])   

    # Layer  5
    x = MaxPool2D(pool_size=(2, 2), strides=2, padding='same', name = 'max_5')(x)
    
    # Layer  6
    x = _conv_block(x, [{'filter': 128, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 6}])   
    
    # Layer  7
    x = MaxPool2D(pool_size=(2, 2), strides=2, padding='same', name = 'max_7')(x)
    
    # Layer  8
    x = _conv_block(x, [{'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 8}])   
    layer_8 = x
    
    # Layer  9
    x = MaxPool2D(pool_size=(2, 2), strides=2, padding='same', name = 'max_9')(x)
    
    # Layer  10
    x = _conv_block(x, [{'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 10}])
    layer_10 = x
    
    # Layer  11
    x = MaxPool2D(pool_size=(2, 2), strides=1, padding='same', name = 'max_11')(x)
    
    # Layer  12
    x = _conv_block(x, [{'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 12}])

    
    ###########
    
    # Layer  13
    x = _conv_block(x, [{'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 13}]) 
    layer_13 = x
        
    # Layer  14
    x = _conv_block(x, [{'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 14}])     
    
    # Layer  15
    x = _conv_block(x, [{'filter': 255, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 0, 'layer_idx': 15}])    
    
    # Layer  16
    yolo_16 = x
    
    
    # Layer  17
    x = layer_13

    # Layer  18
    x = _conv_block(x, [{'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 18}])
   
    # Layer  19
    x = UpSampling2D(size=(2, 2), name = 'upsamp_19')(x)

    # Layer  20
    x = concatenate([layer_8, x],  name='concatenate_20')
    
    # Layer  21
    x = _conv_block(x, [{'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 21}])     
    
    # Layer  22
    x = _conv_block(x, [{'filter': 255, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 0, 'layer_idx': 22}])    
    
    # Layer  23
    yolo_23 = x   
                                      
    model = Model(input_image, [yolo_16, yolo_23], name = 'Yolo_v3_tiny')    
    return model
# Out:
# Using TensorFlow backend.
# TensorFlow version: 2.1.0
# Eager execution: True
# Keras version: 2.2.4-tf
# Cuda version: 10.1
# Cudnn version: 7
# Num GPUs Available:  1

# %%
# Define the model
model = make_yolov3_tiny_model()

# %%
from keras.models import Model
import struct

class WeightReader:
    def __init__(self, weight_file):
        with open(weight_file, 'rb') as w_f:
            major,    = struct.unpack('i', w_f.read(4))
            minor,    = struct.unpack('i', w_f.read(4))
            revision, = struct.unpack('i', w_f.read(4))

            if (major*10 + minor) >= 2 and major < 1000 and minor < 1000:
                print("reading 64 bytes")
                w_f.read(8)
            else:
                print("reading 32 bytes")
                w_f.read(4)

            transpose = (major > 1000) or (minor > 1000)
            
            binary = w_f.read()

        self.offset = 0
        self.all_weights = np.frombuffer(binary, dtype='float32')
        
    def read_bytes(self, size):
        self.offset = self.offset + size
        return self.all_weights[self.offset-size:self.offset]

    def load_weights(self, model):
        count = 0
        ncount = 0
        for i in range(23):
            try:

                conv_layer = model.get_layer('convn_' + str(i))
                filter = conv_layer.kernel.shape[-1]
                nweights = np.prod(conv_layer.kernel.shape) # kernel*kernel*c*filter
                
                print("loading weights of convolution #" + str(i)+ "- nb parameters: "+str(nweights+filter))             
                
                if i  in [15, 22]:
                    print("Special processing for layer "+ str(i))
                    bias  = self.read_bytes(filter) # bias
                    weights = self.read_bytes(nweights) # weights
                
                else:                    
                    bias  = self.read_bytes(filter) # bias
                    scale = self.read_bytes(filter) # scale
                    mean  = self.read_bytes(filter) # mean
                    var   = self.read_bytes(filter) # variance
                    weights = self.read_bytes(nweights) # weights
                    
                    bias = bias - scale  * mean / (np.sqrt(var + 0.00001)) #normalize bias

                    weights = np.reshape(weights,(filter,int(nweights/filter)))  #normalize weights
                    A = scale / (np.sqrt(var + 0.00001))
                    A= np.expand_dims(A,axis=0)
                    weights = weights* A.T
                    weights = np.reshape(weights,(nweights))
                

                weights = weights.reshape(list(reversed(conv_layer.get_weights()[0].shape)))                 
                weights = weights.transpose([2,3,1,0])
                
                if len(conv_layer.get_weights()) > 1:
                    a=conv_layer.set_weights([weights, bias])
                else:    
                    a=conv_layer.set_weights([weights])
                
                count = count+1
                ncount = ncount+nweights+filter
             
            except ValueError:
                print("no convolution #" + str(i)) 
        
        print(count, "Conv normalized layers loaded ", ncount, " parameters")
    
    def reset(self):
        self.offset = 0

# %%
# Get and compute the weights
weight_reader = WeightReader('models/yolo/yolov3-tiny.weights')
weight_reader.load_weights(model)
# Out:
# reading 64 bytes
# loading weights of convolution #0- nb parameters: 448
# no convolution #1
# loading weights of convolution #2- nb parameters: 4640
# no convolution #3
# loading weights of convolution #4- nb parameters: 18496
# no convolution #5
# loading weights of convolution #6- nb parameters: 73856
# no convolution #7
# loading weights of convolution #8- nb parameters: 295168
# no convolution #9
# loading weights of convolution #10- nb parameters: 1180160
# no convolution #11
# loading weights of convolution #12- nb parameters: 4719616
# loading weights of convolution #13- nb parameters: 262400
# loading weights of convolution #14- nb parameters: 1180160
# loading weights of convolution #15- nb parameters: 130815
# Special processing for layer 15
# no convolution #16
# no convolution #17
# loading weights of convolution #18- nb parameters: 32896
# no convolution #19
# no convolution #20
# loading weights of convolution #21- nb parameters: 884992
# loading weights of convolution #22- nb parameters: 65535
# Special processing for layer 22
# 13 Conv normalized layers loaded  8849182  parameters

# %%
# save the model to file
! rm models\yolo\yolov3-tiny.h5

model.save('models/yolo/yolov3-tiny.h5')
! dir models\yolo\*.h5
# Out:
#  Le volume dans le lecteur C s'appelle Windows
#  Le num‚ro de s‚rie du volume est CCDC-AB26
#
#  R‚pertoire de C:\Users\edh\yolo4\Yolov-4\models\yolo
#
# 02/07/2020  23:50        35ÿ584ÿ360 yolov3-tiny.h5
# 25/06/2020  00:03       257ÿ812ÿ724 yolov4.h5
#                2 fichier(s)      293ÿ397ÿ084 octets
#                0 R‚p(s)  284ÿ463ÿ104ÿ000 octets libres

# %%
# Load the model
from keras.models import load_model, Model
yolo_model = load_model("models/yolo/yolov3-tiny.h5")
# Out:
# C:\Users\edh\Anaconda3\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
# Freeze the backbone

# Fine-tune from this layer onwards
fine_tune_at = "convn_13"

# Freeze all the layers before the `fine_tune_at` layer
train = False
for l in yolo_model.layers:
  if l.name == fine_tune_at:
        train = True        
  l.trainable =  train
    

# Display the trainable indicator
for l in yolo_model.layers:
    print("layer ",l.name, " trainable: ", l.trainable)
# Out:
# layer  input_0  trainable:  False
# layer  convn_0  trainable:  False
# layer  BN_0  trainable:  False
# layer  leaky_0  trainable:  False
# layer  max_1  trainable:  False
# layer  convn_2  trainable:  False
# layer  BN_2  trainable:  False
# layer  leaky_2  trainable:  False
# layer  max_3  trainable:  False
# layer  convn_4  trainable:  False
# layer  BN_4  trainable:  False
# layer  leaky_4  trainable:  False
# layer  max_5  trainable:  False
# layer  convn_6  trainable:  False
# layer  BN_6  trainable:  False
# layer  leaky_6  trainable:  False
# layer  max_7  trainable:  False
# layer  convn_8  trainable:  False
# layer  BN_8  trainable:  False
# layer  leaky_8  trainable:  False
# layer  max_9  trainable:  False
# layer  convn_10  trainable:  False
# layer  BN_10  trainable:  False
# layer  leaky_10  trainable:  False
# layer  max_11  trainable:  False
# layer  convn_12  trainable:  False
# layer  BN_12  trainable:  False
# layer  leaky_12  trainable:  False
# layer  convn_13  trainable:  True
# layer  BN_13  trainable:  True
# layer  leaky_13  trainable:  True
# layer  convn_18  trainable:  True
# layer  BN_18  trainable:  True
# layer  leaky_18  trainable:  True
# layer  upsamp_19  trainable:  True
# layer  concatenate_20  trainable:  True
# layer  convn_14  trainable:  True
# layer  convn_21  trainable:  True
# layer  BN_14  trainable:  True
# layer  BN_21  trainable:  True
# layer  leaky_14  trainable:  True
# layer  leaky_21  trainable:  True
# layer  convn_15  trainable:  True
# layer  convn_22  trainable:  True
# layer  BN_15  trainable:  True
# layer  BN_22  trainable:  True

# %%
def read_labels(labels_path):
    with open(labels_path) as f:
        labels = f.readlines()
    labels = [c.strip() for c in labels]
    return labels

# %%
# Load the labels
labels = read_labels("models/yolo/coco_classes.txt")
print(labels)
print("nb labels: ",len(labels))
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
# nb labels:  80

# %%
NETWORK_W        = 416
NETWORK_H        = 416
NB_BOX           = 3
NB_CLASS         = len(labels)
OBJ_THRESHOLD    = 0.3
NMS_THRESHOLD    = 0.3
grids = [(13,13), (26,26)]
anchors = [[81,82,  135,169,  344,319], [10,14,  23,27,  37,58]]
scales_x_y = [1.0, 1.0]

NO_OBJECT_SCALE  = 1.0
OBJECT_SCALE     = 5.0
COORD_SCALE      = 1.0
CLASS_SCALE      = 1.0

BATCH_SIZE       = 32
TRUE_BOX_BUFFER  = 50

# %%
def _interval_overlap(interval_a, interval_b):
    x1, x2 = interval_a
    x3, x4 = interval_b
    if x3 < x1:
        if x4 < x1:
            return 0
        else:
            return min(x2,x4) - x1
    else:
        if x2 < x3:
            return 0
        else:
            return min(x2,x4) - x3
     
        

def bbox_iou(box1, box2):
    intersect_w = _interval_overlap([box1.xmin, box1.xmax], [box2.xmin, box2.xmax])
    intersect_h = _interval_overlap([box1.ymin, box1.ymax], [box2.ymin, box2.ymax])
    
    intersect = intersect_w * intersect_h
    
    w1, h1 = box1.xmax-box1.xmin, box1.ymax-box1.ymin
    w2, h2 = box2.xmax-box2.xmin, box2.ymax-box2.ymin
    
    union = w1*h1 + w2*h2 - intersect
    
    return float(intersect) / union


class BoundBox:
    def __init__(self, xmin, ymin, xmax, ymax, objness = None, classes = None):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax
        self.objness = objness
        self.classes = classes
        self.label = -1
        self.score = -1
 
    def get_label(self):
        if self.label == -1:
            self.label = np.argmax(self.classes)
 
        return self.label
 
    def get_score(self):
        if self.score == -1:
            self.score = self.classes[self.get_label()]
 
        return self.score

# %%
import xml.etree.ElementTree as ET
import pickle
import os
from os import listdir, getcwd
from os.path import join

def convert(image_wh, box, grid_w, grid_h, Boxanchor, yolo_id):
    dw = image_wh[0]/ grid_w
    dh = image_wh[1]/ grid_h
    center_x = (box[0] + box[1])/2.0
    center_x = center_x / dw
    center_y = (box[2] + box[3])/2.0
    center_y = center_y / dh
    
    grid_x = int(np.floor(center_x))
    grid_y = int(np.floor(center_y))
    
    if grid_x < grid_w and grid_y < grid_h:
        w = (box[1] - box[0]) / dw
        h = (box[3] - box[2]) / dh
        
        # find the anchor that best predicts this box
        best_anchor = -1
        max_iou     = -1
    
        shifted_box = BoundBox(0,0,w,h)
    
        for i in range(len(anchors[yolo_id])//2):
            iou    = bbox_iou(shifted_box, Boxanchor[i])                   
            if max_iou < iou:
                best_anchor = i
                max_iou     = iou
    
        return (center_x,center_y,w,h,grid_x,grid_y,best_anchor)
    
    else: # not compatible with the grid size
        return (0,0,0,0,0,0,-1)
    

def convert_annotation(year, image_set, image_id, grid_w, grid_h, Boxanchor, yolo_id, VOC_path):
    in_file = open(VOC_path+'VOC%s\\Annotations\\%s.xml'%(year, image_id))
    out_file = open('VOCdevkit\\VOC%s_%s\\tiny_labels_%s\\%s.txt'%(year, image_set, yolo_id, image_id), 'w')
    tree=ET.parse(in_file)
    root = tree.getroot()
    size = root.find('size')
    image_w = int(size.find('width').text)
    image_h = int(size.find('height').text)

    for obj in root.iter('object'):
        difficult = obj.find('difficult').text
        cls = obj.find('name').text
        if cls not in labels or int(difficult)==1:
            continue
        cls_id = labels.index(cls)
        
        xmlbox = obj.find('bndbox')
        b = (float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text))
        bb = convert((image_w,image_h), b, grid_w, grid_h, Boxanchor, yolo_id)
        
        if bb[-1] != -1:
            out_file.write(str(cls_id) + " " + " ".join([str(a) for a in bb]) + '\n')


def build_label_files (year, image_set, VOC_path):
    yolo_id = 0
    
    for grid_w, grid_h in grids:
        print("grid :",grid_w, grid_h)

        Boxanchor= [BoundBox(0, 0, anchors[yolo_id][2*i], anchors[yolo_id][2*i+1]) for i in range(int(len(anchors[yolo_id])//2))]
       
        if not os.path.exists('VOCdevkit\\VOC%s_%s\\tiny_labels_%s\\' %(year, image_set, yolo_id)):
            os.makedirs('VOCdevkit\\VOC%s_%s\\tiny_labels_%s\\' %(year, image_set, yolo_id))
        
        image_ids = open(VOC_path+'VOC%s\\ImageSets\\Main\\%s.txt'%(year, image_set)).read().strip().split()

        for image_id in image_ids:
            convert_annotation(year, image_set, image_id, grid_w, grid_h, Boxanchor, yolo_id, VOC_path)
            
        yolo_id+=1
    return

# %%
# Build the label files for training
VOC_path = '..\\train\\VOCdevkit\\'
build_label_files ('2012', 'train', VOC_path)
# Out:
# grid : 13 13
# grid : 26 26

# %%
# Build the label files for validation
build_label_files ('2012', 'val', VOC_path)
# Out:
# grid : 13 13
# grid : 26 26

# %%
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

# load and prepare an image
def load_image_pixels(filename, shape):
    # load the image to get its shape
    image = load_img(filename)
    width, height = image.size
    # load the image with the required size
    image = load_img(filename, interpolation = 'bilinear', target_size=shape)
    # convert to numpy array
    image = img_to_array(image)
    # scale pixel values to [0, 1]
    image = image.astype('float32')
    image /= 255.0

    # add a dimension so that we have one sample
    image = expand_dims(image, 0)
    
    return image, width, height

# %%
def build_train (year, image_set, nb_train, VOC_path):
 
    train_x  = np.zeros ((nb_train, NETWORK_H, NETWORK_W, 3), dtype=np.float32)
    train_y0 = np.zeros ((nb_train, grids[0][1], grids[0][0], NB_BOX,(4+1+NB_CLASS)), dtype=np.float32)
    train_y1 = np.zeros ((nb_train, grids[1][1], grids[1][0], NB_BOX,(4+1+NB_CLASS)), dtype=np.float32)
    bc = 0 
        
    image_ids = open(VOC_path+'VOC%s\\ImageSets\\Main\\%s.txt'%(year, image_set)).read().strip().split()

    
    for image_id in image_ids:        
        # Pre-process the image train_x
        img_filename = VOC_path+'VOC%s\\JPEGImages\\%s.jpg'%(year, image_id)
        image, image_w, image_h = load_image_pixels(img_filename, (NETWORK_W, NETWORK_H))
        train_x[bc,:,:,:] = image
        
        # build true predict train_y0 and box b0
        labels_file = open('VOCdevkit\\VOC%s_%s\\tiny_labels_0\\%s.txt'%(year, image_set, image_id), 'r')
        
        rec = np.fromfile(labels_file, dtype=np.float32, sep = " ")
        for i in range(len(rec)//8):
            classid,x,y,w,h,grid_x,grid_y,best_anchor = rec[8*i:8*(i+1)]
            train_y0[bc, int(grid_y),int(grid_x),int(best_anchor), 0:4] = x,y,w,h
            train_y0[bc, int(grid_y),int(grid_x),int(best_anchor), 4] = 1.
            train_y0[bc, int(grid_y),int(grid_x),int(best_anchor), 5+ int(classid)] = 0.9 #Class label smoothing, use 0.9 instead of 1.0 in order to mitigate overfitting.
            
        # build true predict train_y1 and box b1
        labels_file = open('VOCdevkit\\VOC%s_%s\\tiny_labels_1\\%s.txt'%(year, image_set, image_id), 'r')
        
        rec = np.fromfile(labels_file, dtype=np.float32, sep = " ")
        true_box_index = 0
        for i in range(len(rec)//8):
            classid,x,y,w,h,grid_x,grid_y,best_anchor = rec[8*i:8*(i+1)]
            train_y1[bc, int(grid_y),int(grid_x),int(best_anchor), 0:4] = x,y,w,h
            train_y1[bc, int(grid_y),int(grid_x),int(best_anchor), 4] = 1.
            train_y1[bc, int(grid_y),int(grid_x),int(best_anchor), 5+ int(classid)] = 0.9 #Class label smoothing, use 0.9 instead of 1.0 in order to mitigate overfitting.
             
        bc+=1
        if bc == nb_train:
            break
            
    return(train_x,  [train_y0,train_y1])

# %%
# Compute the data for training
VOC_path = '..\\train\\VOCdevkit\\'
nb_data_for_training= 640
train_x, train_y = build_train('2012', 'train', (nb_data_for_training//BATCH_SIZE)*BATCH_SIZE, VOC_path)

# %%
# Compute the data for validation
nb_data_for_validation= 320
val_x, val_y = build_train('2012', 'val', (nb_data_for_validation//BATCH_SIZE)*BATCH_SIZE, VOC_path)

# %%
def custom_loss(y_true, y_pred):
   
    print("TensorFlow version: {}".format(tf.__version__))
    print("Eager execution: {}".format(tf.executing_eagerly()))
    print("Keras version: {}".format(tf.keras.__version__))
   
    print(y_pred.shape)
    grid_h, grid_w = y_pred.shape[1:3] 
    print ("grid_h, grid_w",grid_h, grid_w)
    
    if grid_h == 13:
        anchor = anchors[0]
    else:    
        anchor = anchors[1]     
        
    mask_shape = tf.shape(y_true)[:4]
    print ("mask_shape",mask_shape)

    
    cell_x = tf.cast((tf.reshape(tf.tile(tf.range(grid_w), [grid_h]), (1, grid_h, grid_w, 1, 1))),dtype=tf.float32)
    cell_y = tf.transpose(cell_x, (0,2,1,3,4))
    cell_grid = tf.tile(tf.concat([cell_x,cell_y], -1), [BATCH_SIZE, 1, 1, NB_BOX, 1])
    
    
    ######  prediction
    y_pred = tf.reshape(y_pred, (BATCH_SIZE, grid_h, grid_w, NB_BOX, NB_CLASS+5))

    ### adjust x and y  
    pred_box_xy = tf.sigmoid(y_pred[..., :2]) # x, y)
    pred_box_xy = pred_box_xy + cell_grid
    
    ### adjust w and h
    pred_box_wh = tf.exp(y_pred[..., 2:4]) * np.reshape(anchor, [1,1,1,NB_BOX,2])
    
    ### adjust objectness
    pred_box_obj = tf.sigmoid(y_pred[..., 4])
    
    ### adjust class probabilities
    pred_box_class = tf.sigmoid(y_pred[..., 5:])
    
    
    ######  true
    y_true = tf.reshape(y_true, (BATCH_SIZE, grid_h, grid_w, NB_BOX, NB_CLASS+5))
    print ("y_true", y_true.shape)

    ### adjust x and y  
    true_box_xy = y_true[..., :2] # x, y
    
    ### adjust w and h
    true_box_wh = y_true[..., 2:4]
    
    ### adjust objectness
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half

    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half       

    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas + 1e-10
    iou_scores  = tf.truediv(intersect_areas, union_areas)
   
    true_box_obj = iou_scores * y_true[..., 4]
    
    ### adjust class probabilities
    true_box_class = tf.argmax(y_true[..., 5:], -1)

    
    
    ######  coefficients   
   
    ### coordinate mask: simply the position of the ground truth boxes (the predictors)
    ### is 1 when there is an object in the cell i, else 0.
    coord_mask = tf.zeros(mask_shape)
    coord_mask = tf.expand_dims(y_true[..., 4], axis=-1) * COORD_SCALE
    print("sum coord_mask",tf.reduce_sum(coord_mask))
    
    ### objectness mask: penelize predictors + penalize boxes with low IOU
    # penalize the confidence of the boxes, which have IOU with some ground truth box < 0.6
    for i in range(BATCH_SIZE):
        bd = y_true[i,:,:,:,:4]
        nozero = tf.not_equal(bd, tf.zeros((grid_h, grid_w, NB_BOX, 4)))
        bdd = tf.boolean_mask(bd, nozero)
        s=tf.squeeze(tf.size(bdd)//4)
        c= tf.zeros((50-s,4))
        bdd=tf.reshape(bdd, (s,4))
        bdd = tf.concat([bdd,c],axis=0)
        bdd = tf.expand_dims(bdd,0)
        bdd = tf.expand_dims(bdd,0)
        bdd = tf.expand_dims(bdd,0)
        bdd = tf.expand_dims(bdd,0)
        if (i==0):
            true_boxes =bdd
        else:
            true_boxes = tf.concat([true_boxes,bdd], axis=0)  
    
    true_xy = true_boxes[..., 0:2]
    true_wh = true_boxes[..., 2:4]
    true_wh_half = true_wh / 2.
    true_mins    = true_xy - true_wh_half
    true_maxes   = true_xy + true_wh_half
    
    pred_xy = tf.expand_dims(pred_box_xy, 4)
    pred_wh = tf.expand_dims(pred_box_wh, 4)
    
    pred_wh_half = pred_wh / 2.
    pred_mins    = pred_xy - pred_wh_half
    pred_maxes   = pred_xy + pred_wh_half    
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_wh[..., 0] * true_wh[..., 1]
    pred_areas = pred_wh[..., 0] * pred_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)

    best_ious = tf.reduce_max(iou_scores, axis=4)
    print("best_ious", tf.reduce_max(best_ious))
    
    obj_mask = tf.zeros(mask_shape)
    obj_mask = tf.cast((best_ious < 0.6),dtype=tf.float32) * (1 - y_true[..., 4]) * NO_OBJECT_SCALE
    obj_mask = obj_mask + y_true[..., 4] * OBJECT_SCALE

    print("sum obj_mask",tf.reduce_sum(obj_mask))
    
    ### class mask: simply the position of the ground truth boxes (the predictors)
    ### is 1 when there is a particular class is predicted, else 0.
    class_mask = tf.zeros(mask_shape)
    class_weights = np.ones(NB_CLASS, dtype='float32')
    class_mask = y_true[..., 4] * tf.gather(class_weights, true_box_class) * CLASS_SCALE
    print("sum class_mask",tf.reduce_sum(class_mask))
    
    nb_coord_box = tf.reduce_sum(tf.cast((coord_mask > 0.0),dtype=tf.float32))
    nb_obj_box  = tf.reduce_sum(tf.cast((obj_mask  > 0.0),dtype=tf.float32))
    nb_class_box = tf.reduce_sum(tf.cast((class_mask > 0.0),dtype=tf.float32))
    print("nb_coord_box",nb_coord_box)
    print("nb_obj_box",nb_obj_box)
    print("nb_class_box",nb_class_box) 
      
    ### loss
    loss_xy    = tf.reduce_sum(coord_mask * tf.square(true_box_xy - pred_box_xy)) / (nb_coord_box + 1e-6) / 2.
    loss_wh    = tf.reduce_sum(coord_mask * tf.square(tf.sqrt(tf.abs(true_box_wh)) - tf.sqrt(tf.abs(pred_box_wh)))) / (nb_coord_box + 1e-6) / 2.
    loss_obj   = tf.reduce_sum(obj_mask * tf.square(true_box_obj-pred_box_obj)) / (nb_obj_box + 1e-6) / 2.
    loss_class = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=true_box_class, logits=pred_box_class)
    loss_class = tf.reduce_sum(class_mask * loss_class) / (nb_class_box + 1e-6)

    print("loss_xy",loss_xy.shape)
    print("sum loss_xy",tf.reduce_sum(loss_xy))
    
    print("loss_wh",loss_wh.shape)
    print("sum loss_wh",tf.reduce_sum(loss_wh))
    
    print("loss_obj",loss_obj.shape)
    print("sum loss_obj",tf.reduce_sum(loss_obj))
        
    print("loss_class",loss_class.shape)
    print("sum loss_class",tf.reduce_sum(loss_class))
    
    loss = loss_xy + loss_wh + loss_obj + loss_class
    print("loss",loss.shape)
    print()
    return loss

# %%
# Choose the optimizer
optimizer = tf.keras.optimizers.Adam(lr=0.5e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
#optimizer = tf.keras.optimizers.SGD(lr=1e-4, decay=0.0005, momentum=0.9)
#optimizer = tf.keras.optimizers.SGD.RMSprop(lr=1e-4, rho=0.9, epsilon=1e-08, decay=0.0)

# %%
# Compile the model using the custom loss function defined above
yolo_model.compile(loss=custom_loss, optimizer=optimizer)
# Out:
# TensorFlow version: 2.1.0
# Eager execution: False
# Keras version: 2.2.4-tf
# (None, 13, 13, 255)
# grid_h, grid_w 13 13
# mask_shape Tensor("loss/BN_15_loss/custom_loss/strided_slice:0", shape=(4,), dtype=int32)
# y_true (32, 13, 13, 3, 85)
# sum coord_mask Tensor("loss/BN_15_loss/custom_loss/Sum:0", shape=(), dtype=float32)
# best_ious Tensor("loss/BN_15_loss/custom_loss/Max_1:0", shape=(), dtype=float32)
# sum obj_mask Tensor("loss/BN_15_loss/custom_loss/Sum_1:0", shape=(), dtype=float32)
# sum class_mask Tensor("loss/BN_15_loss/custom_loss/Sum_2:0", shape=(), dtype=float32)
# nb_coord_box Tensor("loss/BN_15_loss/custom_loss/Sum_3:0", shape=(), dtype=float32)
# nb_obj_box Tensor("loss/BN_15_loss/custom_loss/Sum_4:0", shape=(), dtype=float32)
# nb_class_box Tensor("loss/BN_15_loss/custom_loss/Sum_5:0", shape=(), dtype=float32)
# loss_xy ()
# sum loss_xy Tensor("loss/BN_15_loss/custom_loss/Sum_10:0", shape=(), dtype=float32)
# loss_wh ()
# sum loss_wh Tensor("loss/BN_15_loss/custom_loss/Sum_11:0", shape=(), dtype=float32)
# loss_obj ()
# sum loss_obj Tensor("loss/BN_15_loss/custom_loss/Sum_12:0", shape=(), dtype=float32)
# loss_class ()
# sum loss_class Tensor("loss/BN_15_loss/custom_loss/Sum_13:0", shape=(), dtype=float32)
# loss ()
#
# TensorFlow version: 2.1.0
# Eager execution: False
# Keras version: 2.2.4-tf
# (None, 26, 26, 255)
# grid_h, grid_w 26 26
# mask_shape Tensor("loss/BN_22_loss/custom_loss/strided_slice:0", shape=(4,), dtype=int32)
# y_true (32, 26, 26, 3, 85)
# sum coord_mask Tensor("loss/BN_22_loss/custom_loss/Sum:0", shape=(), dtype=float32)
# best_ious Tensor("loss/BN_22_loss/custom_loss/Max_1:0", shape=(), dtype=float32)
# sum obj_mask Tensor("loss/BN_22_loss/custom_loss/Sum_1:0", shape=(), dtype=float32)
# sum class_mask Tensor("loss/BN_22_loss/custom_loss/Sum_2:0", shape=(), dtype=float32)
# nb_coord_box Tensor("loss/BN_22_loss/custom_loss/Sum_3:0", shape=(), dtype=float32)
# nb_obj_box Tensor("loss/BN_22_loss/custom_loss/Sum_4:0", shape=(), dtype=float32)
# nb_class_box Tensor("loss/BN_22_loss/custom_loss/Sum_5:0", shape=(), dtype=float32)
# loss_xy ()
# sum loss_xy Tensor("loss/BN_22_loss/custom_loss/Sum_10:0", shape=(), dtype=float32)
# loss_wh ()
# sum loss_wh Tensor("loss/BN_22_loss/custom_loss/Sum_11:0", shape=(), dtype=float32)
# loss_obj ()
# sum loss_obj Tensor("loss/BN_22_loss/custom_loss/Sum_12:0", shape=(), dtype=float32)
# loss_class ()
# sum loss_class Tensor("loss/BN_22_loss/custom_loss/Sum_13:0", shape=(), dtype=float32)
# loss ()

# %%
class CustomCallback(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        print("Starting train")

    def on_train_end(self, logs=None):
        print("Stop train")
        
    def on_epoch_begin(self, epoch, logs=None):
        print("--Start epoch {}".format(epoch))

    def on_epoch_end(self, epoch, logs=None):
        print("--End epoch {}, the average training loss is {:7.2f}, testing loss is {:7.2f}".format(epoch, logs["loss"], logs["val_loss"]))        
        
    def on_train_batch_begin(self, batch, logs=None):
        print("---Start training batch {}, size {}".format(batch,logs["size"]))
        
    def on_train_batch_end(self, batch, logs=None):
        print("---End training batch {}, total loss is {:7.2f}, loss (13*13) is {:7.2f}, loss (26*26) is {:7.2f}"
              .format(batch, logs["loss"],logs["BN_15_loss"],logs["BN_22_loss"]))      

    def on_test_begin(self, logs=None):
        print("-Start testing")
        
    def on_test_end(self, logs=None):
        print("-Stop testing")
    
    def on_test_batch_begin(self, batch, logs=None):
        print("---Start testing batch {}, size {}".format(batch,logs["size"]))
        
    def on_test_batch_end(self, batch, logs=None):
        print("---End testing batch {}, total loss is {:7.2f}, loss (13*13) is {:7.2f}, loss (26*26) is {:7.2f}"
              .format(batch, logs["loss"],logs["BN_15_loss"],logs["BN_22_loss"]))

# %%
# Fit the model including validation data
import datetime
start = datetime.datetime.now()

EScallback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)

history = yolo_model.fit(x=train_x, y=train_y, validation_data = (val_x,val_y), epochs= 10,batch_size =BATCH_SIZE, verbose=2, callbacks=[CustomCallback(),EScallback])

elapsed = datetime.datetime.now()-start
print("elapsed seconds: ",elapsed.seconds)
# Out:
# Train on 640 samples, validate on 320 samples
# Starting train
# Epoch 1/10
# --Start epoch 0
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is  119.16, loss (13*13) is  103.63, loss (26*26) is   15.53
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is  100.13, loss (13*13) is   95.44, loss (26*26) is   14.20
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is  103.35, loss (13*13) is   93.97, loss (26*26) is   13.58
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   90.65, loss (13*13) is   90.58, loss (26*26) is   12.75
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   88.04, loss (13*13) is   88.14, loss (26*26) is   12.13
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   81.58, loss (13*13) is   85.49, loss (26*26) is   11.66
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   70.38, loss (13*13) is   82.32, loss (26*26) is   11.01
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   65.01, loss (13*13) is   79.08, loss (26*26) is   10.71
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   66.44, loss (13*13) is   76.79, loss (26*26) is   10.41
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   63.55, loss (13*13) is   74.53, loss (26*26) is   10.30
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   67.54, loss (13*13) is   73.09, loss (26*26) is   10.17
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   51.26, loss (13*13) is   70.67, loss (26*26) is    9.92
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   56.07, loss (13*13) is   68.93, loss (26*26) is    9.77
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   53.38, loss (13*13) is   67.33, loss (26*26) is    9.57
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   49.37, loss (13*13) is   65.67, loss (26*26) is    9.39
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   50.05, loss (13*13) is   64.17, loss (26*26) is    9.33
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   50.26, loss (13*13) is   62.96, loss (26*26) is    9.17
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   45.74, loss (13*13) is   61.59, loss (26*26) is    9.07
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   50.91, loss (13*13) is   60.66, loss (26*26) is    8.96
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   46.99, loss (13*13) is   59.64, loss (26*26) is    8.86
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   56.23, loss (13*13) is   49.09, loss (26*26) is    7.13
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   56.22, loss (13*13) is   49.35, loss (26*26) is    6.88
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   58.43, loss (13*13) is   50.05, loss (26*26) is    6.91
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   55.40, loss (13*13) is   49.81, loss (26*26) is    6.76
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   52.77, loss (13*13) is   49.20, loss (26*26) is    6.61
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   51.42, loss (13*13) is   48.49, loss (26*26) is    6.59
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   53.78, loss (13*13) is   48.29, loss (26*26) is    6.60
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   53.38, loss (13*13) is   48.17, loss (26*26) is    6.53
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   53.73, loss (13*13) is   48.05, loss (26*26) is    6.54
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   54.53, loss (13*13) is   48.06, loss (26*26) is    6.53
# -Stop testing
#  - 100s - loss: 68.4934 - BN_15_loss: 59.6353 - BN_22_loss: 8.8581 - val_loss: 54.5898 - val_BN_15_loss: 48.0570 - val_BN_22_loss: 6.5328
# --End epoch 0, the average training loss is   68.49, testing loss is   54.59
# Epoch 2/10
# --Start epoch 1
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   39.26, loss (13*13) is   33.05, loss (26*26) is    6.21
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   49.35, loss (13*13) is   37.83, loss (26*26) is    6.47
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   38.32, loss (13*13) is   35.89, loss (26*26) is    6.42
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   37.09, loss (13*13) is   34.73, loss (26*26) is    6.28
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   35.83, loss (13*13) is   33.70, loss (26*26) is    6.27
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   40.35, loss (13*13) is   33.79, loss (26*26) is    6.25
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   49.23, loss (13*13) is   35.10, loss (26*26) is    6.25
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   34.47, loss (13*13) is   34.25, loss (26*26) is    6.24
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   33.93, loss (13*13) is   33.52, loss (26*26) is    6.24
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   30.76, loss (13*13) is   32.65, loss (26*26) is    6.21
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   35.10, loss (13*13) is   32.32, loss (26*26) is    6.20
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   32.55, loss (13*13) is   31.85, loss (26*26) is    6.17
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   34.57, loss (13*13) is   31.58, loss (26*26) is    6.17
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   32.50, loss (13*13) is   31.20, loss (26*26) is    6.18
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   34.76, loss (13*13) is   31.05, loss (26*26) is    6.15
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   28.62, loss (13*13) is   30.55, loss (26*26) is    6.12
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   32.05, loss (13*13) is   30.27, loss (26*26) is    6.12
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   32.92, loss (13*13) is   30.07, loss (26*26) is    6.13
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   30.53, loss (13*13) is   29.75, loss (26*26) is    6.15
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   26.04, loss (13*13) is   29.28, loss (26*26) is    6.13
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   49.32, loss (13*13) is   42.41, loss (26*26) is    6.91
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   49.97, loss (13*13) is   42.95, loss (26*26) is    6.69
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   52.18, loss (13*13) is   43.73, loss (26*26) is    6.76
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   47.04, loss (13*13) is   43.05, loss (26*26) is    6.57
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   44.78, loss (13*13) is   42.23, loss (26*26) is    6.43
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   43.20, loss (13*13) is   41.36, loss (26*26) is    6.38
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   43.85, loss (13*13) is   40.84, loss (26*26) is    6.35
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   45.74, loss (13*13) is   40.72, loss (26*26) is    6.28
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   46.07, loss (13*13) is   40.62, loss (26*26) is    6.29
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   46.91, loss (13*13) is   40.63, loss (26*26) is    6.27
# -Stop testing
#  - 42s - loss: 35.4117 - BN_15_loss: 29.2814 - BN_22_loss: 6.1302 - val_loss: 46.9045 - val_BN_15_loss: 40.6300 - val_BN_22_loss: 6.2745
# --End epoch 1, the average training loss is   35.41, testing loss is   46.90
# Epoch 3/10
# --Start epoch 2
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   33.60, loss (13*13) is   27.65, loss (26*26) is    5.95
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   26.49, loss (13*13) is   24.28, loss (26*26) is    5.76
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   28.88, loss (13*13) is   23.93, loss (26*26) is    5.73
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   28.03, loss (13*13) is   23.56, loss (26*26) is    5.68
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   34.59, loss (13*13) is   24.57, loss (26*26) is    5.75
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   31.82, loss (13*13) is   24.81, loss (26*26) is    5.75
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   27.22, loss (13*13) is   24.38, loss (26*26) is    5.71
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   25.97, loss (13*13) is   23.86, loss (26*26) is    5.72
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   27.16, loss (13*13) is   23.58, loss (26*26) is    5.73
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   26.96, loss (13*13) is   23.36, loss (26*26) is    5.71
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   24.61, loss (13*13) is   22.98, loss (26*26) is    5.68
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   24.97, loss (13*13) is   22.70, loss (26*26) is    5.66
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   25.51, loss (13*13) is   22.48, loss (26*26) is    5.66
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   27.31, loss (13*13) is   22.43, loss (26*26) is    5.65
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   22.99, loss (13*13) is   22.10, loss (26*26) is    5.64
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   23.76, loss (13*13) is   21.85, loss (26*26) is    5.64
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   23.57, loss (13*13) is   21.64, loss (26*26) is    5.62
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   22.24, loss (13*13) is   21.34, loss (26*26) is    5.64
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   28.75, loss (13*13) is   21.43, loss (26*26) is    5.65
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   27.92, loss (13*13) is   21.49, loss (26*26) is    5.63
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   43.41, loss (13*13) is   36.59, loss (26*26) is    6.81
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   43.93, loss (13*13) is   37.08, loss (26*26) is    6.59
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   47.06, loss (13*13) is   38.14, loss (26*26) is    6.66
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   40.07, loss (13*13) is   37.16, loss (26*26) is    6.45
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   37.85, loss (13*13) is   36.15, loss (26*26) is    6.31
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   36.34, loss (13*13) is   35.20, loss (26*26) is    6.25
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   36.04, loss (13*13) is   34.49, loss (26*26) is    6.18
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   38.81, loss (13*13) is   34.32, loss (26*26) is    6.12
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   39.15, loss (13*13) is   34.18, loss (26*26) is    6.11
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   40.58, loss (13*13) is   34.22, loss (26*26) is    6.10
# -Stop testing
#  - 34s - loss: 27.1167 - BN_15_loss: 21.4865 - BN_22_loss: 5.6302 - val_loss: 40.3231 - val_BN_15_loss: 34.2202 - val_BN_22_loss: 6.1029
# --End epoch 2, the average training loss is   27.12, testing loss is   40.32
# Epoch 4/10
# --Start epoch 3
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   23.53, loss (13*13) is   18.01, loss (26*26) is    5.52
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   19.46, loss (13*13) is   16.09, loss (26*26) is    5.40
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   29.03, loss (13*13) is   18.52, loss (26*26) is    5.49
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   20.72, loss (13*13) is   17.76, loss (26*26) is    5.42
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   25.82, loss (13*13) is   18.26, loss (26*26) is    5.45
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   22.67, loss (13*13) is   18.10, loss (26*26) is    5.43
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   25.85, loss (13*13) is   18.45, loss (26*26) is    5.41
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   26.11, loss (13*13) is   18.71, loss (26*26) is    5.44
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   19.05, loss (13*13) is   18.15, loss (26*26) is    5.43
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   20.68, loss (13*13) is   17.88, loss (26*26) is    5.41
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   26.17, loss (13*13) is   18.14, loss (26*26) is    5.41
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   22.98, loss (13*13) is   18.10, loss (26*26) is    5.41
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   26.94, loss (13*13) is   18.38, loss (26*26) is    5.40
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   23.46, loss (13*13) is   18.36, loss (26*26) is    5.39
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   19.64, loss (13*13) is   18.11, loss (26*26) is    5.37
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   26.25, loss (13*13) is   18.28, loss (26*26) is    5.37
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   29.76, loss (13*13) is   18.64, loss (26*26) is    5.37
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   21.96, loss (13*13) is   18.54, loss (26*26) is    5.36
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   23.19, loss (13*13) is   18.50, loss (26*26) is    5.35
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   19.18, loss (13*13) is   18.28, loss (26*26) is    5.34
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   38.28, loss (13*13) is   31.54, loss (26*26) is    6.74
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   38.99, loss (13*13) is   32.14, loss (26*26) is    6.49
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   43.02, loss (13*13) is   33.54, loss (26*26) is    6.56
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   34.85, loss (13*13) is   32.44, loss (26*26) is    6.34
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   32.60, loss (13*13) is   31.35, loss (26*26) is    6.20
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   31.09, loss (13*13) is   30.35, loss (26*26) is    6.12
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   30.42, loss (13*13) is   29.56, loss (26*26) is    6.04
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   33.09, loss (13*13) is   29.31, loss (26*26) is    5.98
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   33.81, loss (13*13) is   29.17, loss (26*26) is    5.96
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   36.40, loss (13*13) is   29.30, loss (26*26) is    5.96
# -Stop testing
#  - 33s - loss: 23.6232 - BN_15_loss: 18.2823 - BN_22_loss: 5.3409 - val_loss: 35.2551 - val_BN_15_loss: 29.2965 - val_BN_22_loss: 5.9586
# --End epoch 3, the average training loss is   23.62, testing loss is   35.26
# Epoch 5/10
# --Start epoch 4
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   27.37, loss (13*13) is   21.98, loss (26*26) is    5.40
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   21.97, loss (13*13) is   19.30, loss (26*26) is    5.37
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   23.19, loss (13*13) is   18.89, loss (26*26) is    5.29
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   18.40, loss (13*13) is   17.48, loss (26*26) is    5.26
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   22.54, loss (13*13) is   17.43, loss (26*26) is    5.27
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   23.47, loss (13*13) is   17.59, loss (26*26) is    5.23
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   19.87, loss (13*13) is   17.19, loss (26*26) is    5.21
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   20.75, loss (13*13) is   17.02, loss (26*26) is    5.18
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   23.07, loss (13*13) is   17.12, loss (26*26) is    5.18
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   16.89, loss (13*13) is   16.58, loss (26*26) is    5.17
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   23.94, loss (13*13) is   16.78, loss (26*26) is    5.17
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   20.46, loss (13*13) is   16.67, loss (26*26) is    5.15
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   20.48, loss (13*13) is   16.56, loss (26*26) is    5.16
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   20.58, loss (13*13) is   16.48, loss (26*26) is    5.16
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   22.62, loss (13*13) is   16.54, loss (26*26) is    5.17
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   19.17, loss (13*13) is   16.39, loss (26*26) is    5.15
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   19.98, loss (13*13) is   16.31, loss (26*26) is    5.15
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   21.73, loss (13*13) is   16.33, loss (26*26) is    5.14
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   21.76, loss (13*13) is   16.35, loss (26*26) is    5.14
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   21.83, loss (13*13) is   16.37, loss (26*26) is    5.14
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   33.88, loss (13*13) is   27.19, loss (26*26) is    6.69
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   34.74, loss (13*13) is   27.89, loss (26*26) is    6.42
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   39.69, loss (13*13) is   29.65, loss (26*26) is    6.45
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   30.70, loss (13*13) is   28.52, loss (26*26) is    6.23
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   28.82, loss (13*13) is   27.47, loss (26*26) is    6.09
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   27.36, loss (13*13) is   26.52, loss (26*26) is    6.01
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   26.15, loss (13*13) is   25.70, loss (26*26) is    5.92
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   28.81, loss (13*13) is   25.41, loss (26*26) is    5.85
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   29.17, loss (13*13) is   25.21, loss (26*26) is    5.83
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   33.03, loss (13*13) is   25.41, loss (26*26) is    5.83
# -Stop testing
#  - 33s - loss: 21.5036 - BN_15_loss: 16.3680 - BN_22_loss: 5.1355 - val_loss: 31.2347 - val_BN_15_loss: 25.4058 - val_BN_22_loss: 5.8289
# --End epoch 4, the average training loss is   21.50, testing loss is   31.23
# Epoch 6/10
# --Start epoch 5
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   16.52, loss (13*13) is   11.59, loss (26*26) is    4.93
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   22.22, loss (13*13) is   14.46, loss (26*26) is    4.92
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   22.05, loss (13*13) is   15.34, loss (26*26) is    4.92
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   19.42, loss (13*13) is   15.10, loss (26*26) is    4.96
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   20.90, loss (13*13) is   15.23, loss (26*26) is    4.99
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   19.46, loss (13*13) is   15.11, loss (26*26) is    4.99
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   21.58, loss (13*13) is   15.33, loss (26*26) is    4.98
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   21.79, loss (13*13) is   15.52, loss (26*26) is    4.98
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   21.66, loss (13*13) is   15.64, loss (26*26) is    4.98
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   18.78, loss (13*13) is   15.45, loss (26*26) is    4.98
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   19.89, loss (13*13) is   15.40, loss (26*26) is    4.99
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   18.17, loss (13*13) is   15.21, loss (26*26) is    4.99
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   20.75, loss (13*13) is   15.26, loss (26*26) is    4.99
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   21.03, loss (13*13) is   15.31, loss (26*26) is    4.99
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   22.79, loss (13*13) is   15.46, loss (26*26) is    5.00
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   17.91, loss (13*13) is   15.30, loss (26*26) is    5.00
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   20.50, loss (13*13) is   15.32, loss (26*26) is    5.00
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   16.13, loss (13*13) is   15.10, loss (26*26) is    4.99
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   20.92, loss (13*13) is   15.14, loss (26*26) is    4.99
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   19.56, loss (13*13) is   15.12, loss (26*26) is    4.99
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   29.91, loss (13*13) is   23.18, loss (26*26) is    6.73
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   30.59, loss (13*13) is   23.84, loss (26*26) is    6.41
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   36.49, loss (13*13) is   25.92, loss (26*26) is    6.41
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   27.04, loss (13*13) is   24.83, loss (26*26) is    6.18
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   25.52, loss (13*13) is   23.87, loss (26*26) is    6.04
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   24.19, loss (13*13) is   23.01, loss (26*26) is    5.95
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   22.73, loss (13*13) is   22.22, loss (26*26) is    5.85
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   25.02, loss (13*13) is   21.91, loss (26*26) is    5.78
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   25.16, loss (13*13) is   21.67, loss (26*26) is    5.74
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   30.30, loss (13*13) is   21.95, loss (26*26) is    5.75
# -Stop testing
#  - 33s - loss: 20.1012 - BN_15_loss: 15.1157 - BN_22_loss: 4.9855 - val_loss: 27.6951 - val_BN_15_loss: 21.9457 - val_BN_22_loss: 5.7493
# --End epoch 5, the average training loss is   20.10, testing loss is   27.70
# Epoch 7/10
# --Start epoch 6
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   19.59, loss (13*13) is   14.64, loss (26*26) is    4.95
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   20.03, loss (13*13) is   14.90, loss (26*26) is    4.91
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   17.08, loss (13*13) is   14.05, loss (26*26) is    4.85
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   16.94, loss (13*13) is   13.60, loss (26*26) is    4.81
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   20.98, loss (13*13) is   14.09, loss (26*26) is    4.83
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   18.97, loss (13*13) is   14.10, loss (26*26) is    4.83
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   17.48, loss (13*13) is   13.90, loss (26*26) is    4.82
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   22.08, loss (13*13) is   14.30, loss (26*26) is    4.84
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   21.91, loss (13*13) is   14.57, loss (26*26) is    4.88
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   17.77, loss (13*13) is   14.41, loss (26*26) is    4.87
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   19.95, loss (13*13) is   14.47, loss (26*26) is    4.87
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   17.49, loss (13*13) is   14.32, loss (26*26) is    4.87
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   19.41, loss (13*13) is   14.33, loss (26*26) is    4.87
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   17.00, loss (13*13) is   14.17, loss (26*26) is    4.87
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   16.39, loss (13*13) is   14.00, loss (26*26) is    4.87
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   19.55, loss (13*13) is   14.04, loss (26*26) is    4.87
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   22.05, loss (13*13) is   14.21, loss (26*26) is    4.88
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   18.20, loss (13*13) is   14.18, loss (26*26) is    4.87
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   19.82, loss (13*13) is   14.22, loss (26*26) is    4.87
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   19.13, loss (13*13) is   14.21, loss (26*26) is    4.88
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   26.36, loss (13*13) is   19.54, loss (26*26) is    6.82
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   26.79, loss (13*13) is   20.16, loss (26*26) is    6.42
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   33.45, loss (13*13) is   22.49, loss (26*26) is    6.38
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   23.75, loss (13*13) is   21.44, loss (26*26) is    6.15
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   22.47, loss (13*13) is   20.57, loss (26*26) is    6.00
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   21.22, loss (13*13) is   19.78, loss (26*26) is    5.90
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   19.90, loss (13*13) is   19.06, loss (26*26) is    5.79
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   21.73, loss (13*13) is   18.74, loss (26*26) is    5.72
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   21.80, loss (13*13) is   18.49, loss (26*26) is    5.67
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   27.70, loss (13*13) is   18.83, loss (26*26) is    5.69
# -Stop testing
#  - 34s - loss: 19.0905 - BN_15_loss: 14.2096 - BN_22_loss: 4.8809 - val_loss: 24.5174 - val_BN_15_loss: 18.8260 - val_BN_22_loss: 5.6914
# --End epoch 6, the average training loss is   19.09, testing loss is   24.52
# Epoch 8/10
# --Start epoch 7
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   16.62, loss (13*13) is   11.89, loss (26*26) is    4.73
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   17.62, loss (13*13) is   12.38, loss (26*26) is    4.74
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   21.30, loss (13*13) is   13.73, loss (26*26) is    4.78
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   18.05, loss (13*13) is   13.62, loss (26*26) is    4.78
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   20.59, loss (13*13) is   14.04, loss (26*26) is    4.80
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   17.57, loss (13*13) is   13.84, loss (26*26) is    4.79
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   18.03, loss (13*13) is   13.75, loss (26*26) is    4.79
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   17.64, loss (13*13) is   13.64, loss (26*26) is    4.79
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   18.19, loss (13*13) is   13.63, loss (26*26) is    4.77
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   18.44, loss (13*13) is   13.63, loss (26*26) is    4.78
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   17.82, loss (13*13) is   13.58, loss (26*26) is    4.77
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   18.81, loss (13*13) is   13.61, loss (26*26) is    4.78
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   18.59, loss (13*13) is   13.63, loss (26*26) is    4.78
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   19.41, loss (13*13) is   13.70, loss (26*26) is    4.78
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   19.12, loss (13*13) is   13.73, loss (26*26) is    4.79
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   15.88, loss (13*13) is   13.57, loss (26*26) is    4.79
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   18.37, loss (13*13) is   13.56, loss (26*26) is    4.80
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   18.44, loss (13*13) is   13.55, loss (26*26) is    4.81
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   18.28, loss (13*13) is   13.54, loss (26*26) is    4.81
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   18.75, loss (13*13) is   13.57, loss (26*26) is    4.81
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   23.06, loss (13*13) is   16.05, loss (26*26) is    7.01
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   23.10, loss (13*13) is   16.60, loss (26*26) is    6.47
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   30.04, loss (13*13) is   18.99, loss (26*26) is    6.41
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   20.86, loss (13*13) is   18.10, loss (26*26) is    6.16
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   19.61, loss (13*13) is   17.34, loss (26*26) is    6.00
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   18.64, loss (13*13) is   16.67, loss (26*26) is    5.88
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   17.41, loss (13*13) is   16.05, loss (26*26) is    5.77
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   19.02, loss (13*13) is   15.77, loss (26*26) is    5.70
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   18.73, loss (13*13) is   15.51, loss (26*26) is    5.65
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   24.78, loss (13*13) is   15.85, loss (26*26) is    5.67
# -Stop testing
#  - 33s - loss: 18.3760 - BN_15_loss: 13.5694 - BN_22_loss: 4.8065 - val_loss: 21.5247 - val_BN_15_loss: 15.8525 - val_BN_22_loss: 5.6722
# --End epoch 7, the average training loss is   18.38, testing loss is   21.52
# Epoch 9/10
# --Start epoch 8
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   19.02, loss (13*13) is   14.33, loss (26*26) is    4.69
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   17.40, loss (13*13) is   13.57, loss (26*26) is    4.64
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   17.03, loss (13*13) is   13.16, loss (26*26) is    4.66
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   19.42, loss (13*13) is   13.51, loss (26*26) is    4.71
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   18.10, loss (13*13) is   13.46, loss (26*26) is    4.74
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   18.53, loss (13*13) is   13.49, loss (26*26) is    4.76
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   16.87, loss (13*13) is   13.31, loss (26*26) is    4.75
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   16.09, loss (13*13) is   13.06, loss (26*26) is    4.75
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   17.70, loss (13*13) is   13.04, loss (26*26) is    4.76
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   16.93, loss (13*13) is   12.96, loss (26*26) is    4.75
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   16.18, loss (13*13) is   12.83, loss (26*26) is    4.74
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   17.59, loss (13*13) is   12.83, loss (26*26) is    4.75
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   19.90, loss (13*13) is   12.99, loss (26*26) is    4.76
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   18.39, loss (13*13) is   13.04, loss (26*26) is    4.76
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   19.38, loss (13*13) is   13.15, loss (26*26) is    4.76
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   15.53, loss (13*13) is   13.00, loss (26*26) is    4.75
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   16.39, loss (13*13) is   12.93, loss (26*26) is    4.75
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   16.87, loss (13*13) is   12.88, loss (26*26) is    4.74
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   17.80, loss (13*13) is   12.90, loss (26*26) is    4.74
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   18.86, loss (13*13) is   12.96, loss (26*26) is    4.74
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   21.05, loss (13*13) is   13.77, loss (26*26) is    7.28
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   20.86, loss (13*13) is   14.36, loss (26*26) is    6.59
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   27.79, loss (13*13) is   16.75, loss (26*26) is    6.48
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   19.07, loss (13*13) is   15.97, loss (26*26) is    6.22
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   18.10, loss (13*13) is   15.33, loss (26*26) is    6.04
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   17.24, loss (13*13) is   14.78, loss (26*26) is    5.91
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   16.37, loss (13*13) is   14.28, loss (26*26) is    5.79
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   17.33, loss (13*13) is   14.01, loss (26*26) is    5.71
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   16.90, loss (13*13) is   13.75, loss (26*26) is    5.66
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   23.77, loss (13*13) is   14.16, loss (26*26) is    5.69
# -Stop testing
#  - 33s - loss: 17.6984 - BN_15_loss: 12.9576 - BN_22_loss: 4.7408 - val_loss: 19.8479 - val_BN_15_loss: 14.1567 - val_BN_22_loss: 5.6913
# --End epoch 8, the average training loss is   17.70, testing loss is   19.85
# Epoch 10/10
# --Start epoch 9
# ---Start training batch 0, size 32
# ---End training batch 0, total loss is   17.49, loss (13*13) is   12.84, loss (26*26) is    4.65
# ---Start training batch 1, size 32
# ---End training batch 1, total loss is   14.97, loss (13*13) is   11.60, loss (26*26) is    4.64
# ---Start training batch 2, size 32
# ---End training batch 2, total loss is   18.37, loss (13*13) is   12.25, loss (26*26) is    4.70
# ---Start training batch 3, size 32
# ---End training batch 3, total loss is   15.88, loss (13*13) is   12.00, loss (26*26) is    4.68
# ---Start training batch 4, size 32
# ---End training batch 4, total loss is   16.93, loss (13*13) is   12.06, loss (26*26) is    4.67
# ---Start training batch 5, size 32
# ---End training batch 5, total loss is   16.55, loss (13*13) is   12.03, loss (26*26) is    4.66
# ---Start training batch 6, size 32
# ---End training batch 6, total loss is   18.08, loss (13*13) is   12.21, loss (26*26) is    4.69
# ---Start training batch 7, size 32
# ---End training batch 7, total loss is   19.12, loss (13*13) is   12.48, loss (26*26) is    4.69
# ---Start training batch 8, size 32
# ---End training batch 8, total loss is   17.50, loss (13*13) is   12.52, loss (26*26) is    4.69
# ---Start training batch 9, size 32
# ---End training batch 9, total loss is   13.85, loss (13*13) is   12.20, loss (26*26) is    4.68
# ---Start training batch 10, size 32
# ---End training batch 10, total loss is   15.15, loss (13*13) is   12.05, loss (26*26) is    4.67
# ---Start training batch 11, size 32
# ---End training batch 11, total loss is   14.74, loss (13*13) is   11.89, loss (26*26) is    4.67
# ---Start training batch 12, size 32
# ---End training batch 12, total loss is   16.07, loss (13*13) is   11.85, loss (26*26) is    4.67
# ---Start training batch 13, size 32
# ---End training batch 13, total loss is   18.71, loss (13*13) is   12.00, loss (26*26) is    4.67
# ---Start training batch 14, size 32
# ---End training batch 14, total loss is   16.93, loss (13*13) is   12.02, loss (26*26) is    4.67
# ---Start training batch 15, size 32
# ---End training batch 15, total loss is   20.81, loss (13*13) is   12.27, loss (26*26) is    4.68
# ---Start training batch 16, size 32
# ---End training batch 16, total loss is   15.36, loss (13*13) is   12.18, loss (26*26) is    4.67
# ---Start training batch 17, size 32
# ---End training batch 17, total loss is   18.19, loss (13*13) is   12.25, loss (26*26) is    4.67
# ---Start training batch 18, size 32
# ---End training batch 18, total loss is   15.42, loss (13*13) is   12.18, loss (26*26) is    4.67
# ---Start training batch 19, size 32
# ---End training batch 19, total loss is   16.45, loss (13*13) is   12.16, loss (26*26) is    4.67
# -Start testing
# ---Start testing batch 0, size 32
# ---End testing batch 0, total loss is   18.89, loss (13*13) is   11.34, loss (26*26) is    7.55
# ---Start testing batch 1, size 32
# ---End testing batch 1, total loss is   18.31, loss (13*13) is   11.87, loss (26*26) is    6.73
# ---Start testing batch 2, size 32
# ---End testing batch 2, total loss is   24.74, loss (13*13) is   14.06, loss (26*26) is    6.58
# ---Start testing batch 3, size 32
# ---End testing batch 3, total loss is   17.06, loss (13*13) is   13.44, loss (26*26) is    6.31
# ---Start testing batch 4, size 32
# ---End testing batch 4, total loss is   16.03, loss (13*13) is   12.89, loss (26*26) is    6.11
# ---Start testing batch 5, size 32
# ---End testing batch 5, total loss is   15.39, loss (13*13) is   12.44, loss (26*26) is    5.96
# ---Start testing batch 6, size 32
# ---End testing batch 6, total loss is   14.92, loss (13*13) is   12.07, loss (26*26) is    5.84
# ---Start testing batch 7, size 32
# ---End testing batch 7, total loss is   15.50, loss (13*13) is   11.85, loss (26*26) is    5.76
# ---Start testing batch 8, size 32
# ---End testing batch 8, total loss is   14.93, loss (13*13) is   11.61, loss (26*26) is    5.70
# ---Start testing batch 9, size 32
# ---End testing batch 9, total loss is   21.61, loss (13*13) is   12.00, loss (26*26) is    5.74
# -Stop testing
#  - 33s - loss: 16.8287 - BN_15_loss: 12.1625 - BN_22_loss: 4.6662 - val_loss: 17.7365 - val_BN_15_loss: 11.9973 - val_BN_22_loss: 5.7392
# --End epoch 9, the average training loss is   16.83, testing loss is   17.74
# Stop train
# elapsed seconds:  423

# %%
# plot learning curves
from matplotlib import pyplot
pyplot.title('Learning Curves')
pyplot.xlabel('Epoch')
pyplot.ylabel('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='val')
pyplot.legend()
pyplot.show()
